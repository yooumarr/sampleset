# %% [markdown]
# # Building an RAG model based chatbot for financial queries.

# %%
pip install PyMuPDF rake-nltk pandas numpy scipy
# Out:
# Requirement already satisfied: PyMuPDF in /usr/local/lib/python3.11/dist-packages (1.25.2)
# Requirement already satisfied: rake-nltk in /usr/local/lib/python3.11/dist-packages (1.0.6)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (1.26.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (1.13.1)
# Requirement already satisfied: nltk<4.0.0,>=3.6.2 in /usr/local/lib/python3.11/dist-packages (from rake-nltk) (3.9.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from nltk<4.0.0,>=3.6.2->rake-nltk) (8.1.8)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from nltk<4.0.0,>=3.6.2->rake-nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.11/dist-packages (from nltk<4.0.0,>=3.6.2->rake-nltk) (2024.11.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from nltk<4.0.0,>=3.6.2->rake-nltk) (4.67.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %% [markdown]
# # Step 1

# %%
import fitz

pdf_document = 'Sample Financial Statement.pdf'
document = fitz.open(pdf_document)

pdf_text = {}

for page_number in range(document.page_count):
  page = document.load_page(page_number)
  text = page.get_text()
  pdf_text[page_number + 1] = text

document.close()

# for page, text in pdf_text.items():
#   print(f"Text from page {page}:\n{text}\n")

# %%
import re

# Function to clean the data
def preprocess_pdf_text(pdf_text):
    processed_text = {}
    for page, text in pdf_text.items():
        text = re.sub(r"\n\s*\n", "\n", text.strip())

        relevant_lines = []
        for line in text.split("\n"):
            if re.search(r"\b(balance sheet|revenue|assets|liabilities|profit|income|expense)\b", line, re.IGNORECASE):
                relevant_lines.append(line)
            elif re.search(r"[\d,]+(\.\d+)?", line):
                relevant_lines.append(line)

        processed_text[page] = "\n".join(relevant_lines)

    return processed_text

cleaned_pdf_text = preprocess_pdf_text(pdf_text)

for page, text in cleaned_pdf_text.items():
    print(f"Cleaned Text from page {page}:\n{text}\n")
# Out:
# Cleaned Text from page 1:
# Condensed Consolidated Balance Sheet ……………………………………………………………………………………
# 1
# Condensed Consolidated Statement of Profit and Loss ………………………………………………………………………
# 2
# 3
# 5
# 1. Overview
# 1.1 Company overview ……………………………………………………………………………………………………
# 7
# 1.2 Basis of preparation of financial statements …………………………………………………………………………
# 7
# 1.3 Basis of consolidation …………………………………………………………………………………………………
# 7
# 1.4 Use of estimates and judgments ………………………………………………………………………………………
# 7
# 1.5 Critical accounting estimates and judgments…………………………………………………………………………
# 8
# 2. Notes to the Interim Condensed Consolidated Financial Statements
# 2.1 Business Combinations ………………………………………………………………………………………………
# 10
# 2.2 Property, plant and equipment ………………………………………………………………………………………
# 12
# 2.3 Goodwill and other intangible assets…………………………………………………………………………………
# 14
# 2.4 Investments ……………………………………………………………………………………………………………
# 15
# 2.5 Loans …………………………………………………………………………………………………………………
# 16
# 2.6 Other financial assets …………………………………………………………………………………………………
# 16
# 2.7 Trade receivables ……………………………………………………………………………………………………
# 16
# 2.8 Cash and cash equivalents ……………………………………………………………………………………………
# 17
# 2.9 Other assets ……………………………………………………………………………………………………………
# 17
# 2.10 Financial instruments ………………………………………………………………………………………………
# 18
# 2.11 Equity ………………………………………………………………………………………………………………
# 22
# 2.12 Other financial liabilities ……………………………………………………………………………………………
# 25
# 2.13 Other liabilities ………………………………………………………………………………………………………
# 25
# 2.14 Provisions ……………………………………………………………………………………………………………
# 26
# 2.15 Income taxes …………………………………………………………………………………………………………
# 27
# 2.16 Revenue from operations ……………………………………………………………………………………………
# 28
# 2.17 Other income, net ……………………………………………………………………………………………………
# 30
# 2.18 Expenses ……………………………………………………………………………………………………………
# 31
# 2.19 Leases ………………………………………………………………………………………………………………
# 32
# 2.20 Basic and diluted shares used in computing earnings per equity share ……………………………………………
# 34
# 2.21 Contingent liabilities and commitments  ……………………………………………………………………………
# 34
# 2.22 Related party transactions ……………………………………………………………………………………………
# 36
# 2.23 Segment reporting ……………………………………………………………………………………………………
# 37
# 2.24 Function wise classification of Condensed Consolidated Statement of Profit and Loss ……………………………
# 39
# for the three months and year ended March 31, 2024
#
# Cleaned Text from page 2:
# March 31, 2024
# March 31, 2023
# ASSETS
# Non-current assets
# Property, plant and equipment
# 2.2
#                               12,370                                13,346
# Right-of-use assets
# 2.19
#                                 6,552                                  6,882
#                                    293                                     288
# 2.3
#                                 7,303                                  7,248
# Other intangible assets
#                                 1,397                                  1,749
# Financial assets
# 2.4
#                               11,708                                12,569
# 2.5
#                                      34                                       39
# Other financial assets
# 2.6
#                                 3,105                                  2,798
# Deferred tax assets (net)
#                                    454                                  1,245
# Income tax assets (net)
#                                 3,045                                  6,453
# Other non-current assets
# 2.9
#                                 2,121                                  2,318
# Total non-current assets
#                               48,382                                54,935
# Current assets
# Financial assets
# 2.4
#                               12,915                                  6,909
# 2.7
#                               30,193                                25,424
# 2.8
#                               14,786                                12,173
# 2.5
#                                    248                                     289
# Other financial assets
# 2.6
#                               12,085                                11,604
# Income tax assets (net)
#                                 6,397                                         6
# Other current assets
# 2.9
#                               12,808                                14,476
# Total current assets
#                               89,432                                70,881
# Total assets
#                             137,814                              125,816
# EQUITY AND LIABILITIES
# 2.11
#                                 2,071                                  2,069
#                               86,045                                73,338
#                               88,116                                75,407
#                                    345                                     388
#                               88,461                                75,795
# Liabilities
# Non-current liabilities
# Financial Liabilities
# Lease liabilities
# 2.19
#                                 6,400                                  7,057
# Other financial liabilities
# 2.12
#                                 2,130                                  2,058
# Deferred tax liabilities (net)
#                                 1,794                                  1,220
# Other non-current liabilities
# 2.13
#                                    235                                     500
# Total non-current liabilities
#                               10,559                                10,835
# Current liabilities
# Financial Liabilities
# Lease liabilities
# 2.19
#                                 1,959                                  1,242
#                                 3,956                                  3,865
# Other financial liabilities
# 2.12
#                               16,959                                18,558
# Other current liabilities
# 2.13
#                               10,539                                10,830
# 2.14
#                                 1,796                                  1,307
# Income tax liabilities (net)
#                                 3,585                                  3,384
# Total current liabilities
#                               38,794                                39,186
# Total equity and liabilities
#                             137,814                              125,816
# 117366W/ W-100018
# Membership No. 039826
# April 18, 2024
# 1
#
# Cleaned Text from page 3:
# (In ₹ crore, except equity share and per equity share data)
# 2024
# 2023
# 2024
# 2023
# Revenue from operations
# 2.16
#                             37,923                             37,441                           153,670                           146,767
# Other income, net
# 2.17
#                               2,729                                  671                               4,711                               2,701
# Total income
#                             40,652                             38,112                           158,381                           149,468
# 2.18
#                             20,393                             20,311                             82,620                             78,359
#                               2,967                               3,116                             12,232                             14,062
#                                  471                                  426                               1,759                               1,525
# 2.18
#                               3,687                               2,886                             13,515                             10,902
#                                  147                                  171                                  677                                  713
#                                  489                                  387                               1,726                               1,684
#                               1,163                               1,121                               4,678                               4,225
#                                  110                                    82                                  470                                  284
# 2.18
#                                  985                               1,146                               4,716                               4,392
#                             30,412                             29,646                           122,393                           116,146
# Profit before tax
#                             10,240                               8,466                             35,988                             33,322
# Tax expense:
# 2.15
#                               1,173                               2,260                               8,390                               9,287
# 2.15
#                               1,092                                    72                               1,350                                  (73)
# Profit for the period
#                               7,975                               6,134                             26,248                             24,108
# Other comprehensive income
# Items that will not be reclassified subsequently to profit or loss
# Remeasurement of the net defined benefit liability/asset, net
#                                    26                                    25                                  120                                      8
# Equity instruments through other comprehensive income, net
#                                  (12)                                  (15)                                    19                                    (7)
#                                    14                                    10                                  139                                      1
# Items that will be reclassified subsequently to profit or loss
# Fair value changes on derivatives designated as cash flow hedge, net
#                                    28                                    36                                    11                                    (7)
#                                (231)                                    61                                  226                                  776
# Fair value changes on investments, net
#                                    37                                    42                                  144                                (256)
#                                (166)                                  139                                  381                                  513
# Total other comprehensive income /(loss), net of tax
#                                (152)                                  149                                  520                                  514
# Total comprehensive income for the period
#                               7,823                               6,283                             26,768                             24,622
# Profit attributable to:
#                               7,969                               6,128                             26,233                             24,095
#                                      6                                      6                                    15                                    13
#                               7,975                               6,134                             26,248                             24,108
# Total comprehensive income attributable to:
#                               7,821                               6,276                             26,754                             24,598
#                                      2                                      7                                    14                                    24
#                               7,823                               6,283                             26,768                             24,622
# Equity shares of par value ₹5/- each
#                               19.25                               14.79                               63.39                               57.63
#                               19.22                               14.77                               63.29                               57.54
# 2.20
#                 4,139,432,133                 4,144,013,195                 4,138,568,090                 4,180,897,857
# 2.20
#                 4,145,052,370                 4,149,555,426                 4,144,680,425                 4,187,731,070
# 117366W/ W-100018
# Membership No. 039826
# April 18, 2024
# Condensed Consolidated Statement of Profit and Loss for the
# Year ended March 31,
# Three months ended March 31,
# 2
#
# Cleaned Text from page 4:
# reserve (2)
# reserves (3)
# income
# income / (loss)
# Balance as at April 1, 2022
#            2,098                 54               139              200         61,313           1,061                606           8,339                16
#                     254                      1,560                       2                    (292)
#             75,350               386          75,736
# Impact on adoption of amendment to Ind AS 37#
#                 —                 —                 —                —              (19)                —                  —                —                —
#                       —                            —                     —                       —                   (19)
#                 —                (19)
#            2,098                 54               139              200         61,294           1,061                606           8,339                16
#                     254                      1,560                       2                    (292)
#             75,331               386          75,717
# Changes in equity for the year ended March 31, 2023
# Profit for the period
#                 —                 —                 —                —         24,095                —                  —                —                —
#                       —                            —                     —                       —             24,095                 13          24,108
# Remeasurement of the net defined benefit liability/asset, net*
#                       —                            —                     —                         8                      8                 —                   8
# Equity instruments through other comprehensive income, net*
#                        (7)                            —                     —                       —                     (7)
#                 —                  (7)
# Fair value changes on derivatives designated as cash flow hedge, net*
#                       —                            —                     (7)                       —                     (7)
#                 —                  (7)
#                       —                         765                     —                       —                  765                 11               776
# Fair value changes on investments, net*
#                       —                            —                     —                    (256)                 (256)
#                 —              (256)
# Total Comprehensive income for the period
#                 —                 —                 —                —         24,095                —                  —                —                —
#                        (7)
#                         765                     (7)                    (248)
#             24,598                 24          24,622
# 2.11)
#                   1                 —                 —                34                —                —                  —                —                —
#                       —                            —                     —                       —                    35                 —                 35
# Employee stock compensation expense (Refer to Note 2.11)
#                 —                 —                 —                —                —                —                514                —                —
#                       —                            —                     —                       —                  514                 —               514
#                 —                 —                 —                —                —                  2                   (2)                —                —
# Buyback of equity shares (Refer to Note 2.11) **
#                (30)                 —                 —            (340)       (11,096)                —                  —                —                —
#                       —                            —                     —                       —            (11,466)
#                 —         (11,466)
#                 —                 —                 —              (19)                (5)                —                  —                —                —
#                       —                            —                     —                       —                   (24)
#                 —                (24)
#                 —                 —                 30                —              (21)                (9)
#                 —                 —                 —                —         (3,139)                —                  —           3,139                —
#                 —                 —                 —                —                (3)                —                  —                —                  3
# 2.11)
#                 —                 —                 —              291                —                —               (291)                —                —
# Income tax benefit arising on exercise of stock options
#                 —                 —                 —                —                —                —                  51                —                —
#                       —                            —                     —                       —                    51                 —                 51
# Dividends (1)
#                 —                 —                 —                —       (13,632)                —                  —                —                —
#                       —                            —                     —                       —            (13,632)
#                 —         (13,632)
#                       —                            —                     —                       —                    —                (22)                (22)
#                 —                 —                 —                —           1,464                —                  —         (1,464)                —
# Balance as at March 31, 2023
#            2,069                 54               169              166         58,957           1,054                878         10,014                19
#                     247                      2,325                     (5)                    (540)
#             75,407               388          75,795
# capital (1)
# Other comprehensive income
# 3
#
# Cleaned Text from page 5:
# reserve (2)
# reserves (3)
# income
# income / (loss)
# Balance as at April 1, 2023
#            2,069                 54               169              166         58,957           1,054                878         10,014                19
#                     247                      2,325                     (5)                    (540)
#             75,407               388          75,795
# Changes in equity for the year ended March 31, 2024
# Profit for the period
#                 —                 —                 —                —         26,233                —                  —                —                —
#                       —                            —                     —                       —             26,233                 15          26,248
# Remeasurement of the net defined benefit liability/asset, net*
#                       —                            —                     —                     120                  120                 —               120
# Equity instruments through other comprehensive income, net*
#                       19                            —                     —                       —                    19                 —                 19
# Fair value changes on derivatives designated as cash flow hedge, net*
#                       —                            —                     11                       —                    11                 —                 11
#                       —                         227                     —                       —                  227                  (1)
#               226
# Fair value changes on investments, net*
#                       —                            —                     —                     144                  144                 —               144
# Total Comprehensive income for the period
#                 —                 —                 —                —         26,233                —                  —                —                —
#                       19                         227                     11                     264             26,754                 14          26,768
# 2.11)
#                   2                 —                 —                  3                —                —                  —                —                —
#                       —                            —                     —                       —                      5                 —                   5
# Employee stock compensation expense (Refer to Note 2.11)
#                 —                 —                 —                —                —                —                639                —                —
#                       —                            —                     —                       —                  639                 —               639
# 2.11)
#                 —                 —                 —              447                —                —               (447)                —                —
#                 —                 —                 —                —                —              160               (160)                —                —
# Income tax benefit arising on exercise of stock options
#                 —                 —                 —                —                —                —                    3                —                —
#                       —                            —                     —                       —                      3                 —                   3
#                 —                 —                 —                —                (3)                —                  —                —                  3
# Dividends (1)
#                 —                 —                 —                —       (14,692)                —                  —                —                —
#                       —                            —                     —                       —            (14,692)
#                 —         (14,692)
#                       —                            —                     —                       —                    —                (39)                (39)
#                       —                            —                     —                       —                    —                (18)                (18)
#                 —                 —                 —                —         (2,957)                —                  —           2,957                —
#                 —                 —                 —                —              867                —                  —            (867)                —
# Balance as at March 31, 2024
#            2,071                 54               169              616         68,405           1,214                913         12,104                22
#                     266                      2,552                       6                    (276)
#             88,116               345          88,461
# ** Including tax on buyback of ₹2,166 crore for the year ended March 31, 2023.
# #  Impact on account of adoption of amendment to Ind AS 37 Provisions, Contingent Liabilities and Contingents Assets
# (1) Net of treasury shares
# 117366W/ W-100018
# Membership No. 039826
# April 18, 2024
# (3) Under the Swiss Code of Obligation, few subsidiaries of Infosys Consulting are required to appropriate a certain percentage of the annual profit to legal reserve which may be used only to cover losses or for measures designed to sustain the Company through difficult times, to prevent unemployment or to
# capital (1)
# Other comprehensive income
# (2) The Special Economic Zone Re-investment Reserve has been created out of the profit of eligible SEZ units in terms of the provisions of Sec 10AA(1)(ii) of Income Tax Act, 1961. The reserve should be utilized by the Group for acquiring new plant and machinery for the purpose of its business in the terms of the
# Sec 10AA(2) of the Income Tax Act, 1961.
# 4
#
# Cleaned Text from page 6:
# 2024
# 2023
# Profit for the period
#                              26,248                                   24,108
# Income tax expense
# 2.15
#                                9,740                                     9,214
#                                4,678                                     4,225
#                               (2,067)                                   (1,817)
#                                   470                                        284
#                                   121                                        283
# Exchange differences on translation of assets and liabilities, net
#                                     76                                        161
# Stock compensation expense
#                                   652                                        519
# Interest on income tax refund
#                               (1,934)                                          —
#                                     75                                        120
#                                1,464                                        508
# Changes in assets and liabilities
# Trade receivables and unbilled revenue
#                               (2,667)                                   (7,076)
# Loans, other financial assets and other assets
#                               (1,172)                                   (3,108)
#                                     91                                      (279)
# Other financial liabilities, other liabilities and provisions
#                               (1,334)                                     4,119
#                              34,441                                   31,261
# Income taxes paid
#                               (9,231)                                   (8,794)
#                              25,210                                   22,467
#                               (2,201)                                   (2,579)
#                                  (847)                                      (996)
#                                   710                                        762
#                                1,768                                     1,525
# 2.1
#                                     —                                      (910)
#                                  (101)                                        (60)
#                                     —                                      (483)
#                                     —                                        483
#                                   128                                          71
#                             (66,191)                                 (70,631)
#                                     —                                      (400)
#                               (8,509)                                 (10,348)
#                             (10,387)                                   (3,003)
#                               (1,526)                                      (249)
#                                     —                                        (27)
#                                     —                                   (1,569)
#                                    (14)                                        (20)
#                                   150                                        221
#                              64,767                                   71,851
#                                9,205                                   10,404
#                                6,479                                     2,298
#                                1,230                                        470
#                                   304                                     1,882
#                                     26                                          99
#                               (5,009)                                   (1,209)
# Cash flows are reported using the indirect method, whereby profit for the period is adjusted for the effects of transactions of a non-cash nature, any
# deferrals or accruals of past or future operating cash receipts or payments and item of income or expenses associated with investing or financing cash
# flows. The cash flows from operating, investing and financing activities of the Group are segregated. The Group considers all highly liquid investments
# Year ended March 31,
# Expenditure on property, plant and equipment and intangibles
# Adjustments to reconcile net profit to net cash provided by operating
# Interest and dividend income
# Payment towards acquisition of business, net of cash acquired
# 5
#
# Cleaned Text from page 7:
# Payment of lease liabilities
#                               (2,024)                                   (1,231)
#                             (14,692)                                 (13,631)
#                                    (39)                                        (22)
#                                    (18)                                          —
#                                       5                                          35
#                                      -                                          132
#                                  (736)                                      (479)
#                                      -                                   (11,499)
#                             (17,504)                                 (26,695)
#                                2,697                                   (5,437)
#                                    (84)                                        138
# 2.8
#                              12,173                                   17,472
# 2.8
#                              14,786                                   12,173
# 2.8
#                                   348                                        362
# 117366W/ W-100018
# Membership No. 039826
# April 18, 2024
# 6
#
# Cleaned Text from page 8:
# 1. Overview
# 1.1 Company overview
# Infosys Limited ('the Company' or Infosys) provides consulting, technology, outsourcing and next-generation digital services, to enable clients to execute
# strategies for their digital transformation. Infosys strategic objective is to build a sustainable organization that remains relevant to the agenda of clients, while
# creating growth opportunities for employees and generating profitable returns for investors. Infosys strategy is to be a navigator for our clients as they ideate,
# The Company is a public limited company incorporated and domiciled in India and has its registered office at Electronics city, Hosur Road, Bengaluru
# 560100, Karnataka, India. The Company has its primary listings on the BSE Ltd. and National Stock Exchange of India Limited. The Company’s American
# The Group's interim condensed consolidated financial statements are approved for issue by the Company's Board of Directors on April 18, 2024.
# 1.2 Basis of preparation of financial statements
# These interim condensed consolidated financial statements are prepared in compliance with Indian Accounting Standard (Ind AS) 34 Interim Financial
# Reporting , under the historical cost convention on accrual basis except for certain financial instruments which are measured at fair values, the provisions of
# the Companies Act, 2013 ('the Act') and guidelines issued by the Securities and Exchange Board of India (SEBI). Accordingly, these interim condensed
# the year ended March 31, 2023. The Ind AS are prescribed under Section 133 of the Act read with Rule 3 of the Companies (Indian Accounting Standards)
# Rules, 2015 and relevant amendment rules issued thereafter.
# As the quarter and year-to-date figures are taken from the source and rounded to the nearest digits, the quarter figures in this statement added up to the figures
# 1.3 Basis of consolidation
# Company, its controlled trusts and its subsidiaries. Control exists when the parent has power over the entity, is exposed, or has rights to variable returns from
# give the ability to direct relevant activities, those which significantly affect the entity's returns. Subsidiaries are consolidated from the date control commences
# Group. Non-controlling interests which represent part of the net profit or loss and net assets of subsidiaries that are not, directly or indirectly, owned or
# controlled by the Company, are excluded.
# 1.4 Use of estimates and judgments
# The preparation of the interim condensed consolidated financial statements in conformity with Ind AS requires the Management to make estimates, judgments
# and assumptions. These estimates, judgments and assumptions affect the application of accounting policies and the reported amounts of assets and liabilities,
# the disclosures of contingent assets and liabilities at the date of the interim condensed consolidated financial statements and reported amounts of revenues and
# the use of assumptions in these financial statements have been disclosed in Note no. 1.5 . Accounting estimates could change from period to period. Actual
# made and, if material, their effects are disclosed in the notes to the interim condensed consolidated financial statements.
# 7
#
# Cleaned Text from page 9:
# 1.5 Critical accounting estimates and judgments
# a. Revenue recognition
# considered for recognition and measurement when the contract has been approved, in writing, by the parties to the contract, the parties to contract are
# committed to perform their respective obligations under the contract, and the contract is legally enforceable. The Group assesses the services promised in a
# ability of the customer to benefit independently from such deliverables, and allocation of transaction price to these distinct performance obligations involves
# Fixed price maintenance revenue is recognized ratably on a straight-line basis when services are performed through an indefinite number of repetitive acts
# over a specified period. Revenue from fixed price maintenance contract is recognized ratably using a percentage of completion method when the pattern of
# types of arrangements, revenue from sales of third-party vendor products or services is recorded net of costs when the Group is acting as an agent between the
# customer and the vendor, and gross when the Group is the principal for the transaction. In doing so, the Group first evaluates whether it obtains control of the
# provide the specified goods or services, inventory risk, pricing discretion and other factors to determine whether it controls the specified goods or services and
# therefore, is acting as a principal or an agent.
# Provisions for estimated losses, if any, on incomplete contracts are recorded in the period in which such losses become probable based on the estimated efforts
# b. Income taxes
# The Group's two major tax jurisdictions are India and the United States, though the Company also files tax returns in other overseas jurisdictions.
# Significant judgments are involved in determining the provision for income taxes, including amount expected to be paid / recovered for uncertain tax
# In assessing the realizability of deferred income tax assets, the Management considers whether some portion or all of the deferred income tax assets will not be
# realized. The ultimate realization of deferred income tax assets is dependent upon the generation of future taxable income during the periods in which the
# temporary differences become deductible. Management considers the scheduled reversals of deferred income tax liabilities, projected future taxable income
# and tax planning strategies in making this assessment. Based on the level of historical taxable income and projections for future taxable income over the
# periods in which the deferred income tax assets are deductible, the Management believes that the Group will realize the benefits of those deductible
# differences. The amount of the deferred income tax assets considered realizable, however, could be reduced in the near term if estimates of future taxable
# income during the carry forward period are reduced (Refer to Notes 2.15).
# c. Business combinations and intangible assets
# Business combinations are accounted for using Ind AS 103, Business Combinations. Ind AS 103 requires the identifiable intangible assets and contingent
# consideration to be fair valued in order to ascertain the fair value of identifiable assets, liabilities and contingent liabilities of the acquiree. These valuations
# are conducted by external valuation experts. Estimates are required to be made in determining the value of contingent consideration, value of option
# arrangements and intangible assets. These measurements are based on information available at the acquisition date and are based on expectations and
# assumptions that have been deemed reasonable by the Management (Refer to Note 2.1).
# d. Property, plant and equipment
# Property, plant and equipment represent a significant proportion of the asset base of the Group. The charge in respect of periodic depreciation is derived after
# assets are determined by the Management at the time the asset is acquired and reviewed periodically, including at each financial year end. The lives are based
# on historical experience with similar assets as well as anticipation of future events, which may impact their life, such as changes in technology (Refer to Note
# 2.2).
# 8
#
# Cleaned Text from page 10:
# than its carrying amount. For the impairment test, goodwill is allocated to the CGU or groups of CGUs which benefit from the synergies of the acquisition and
# are prepared based on current economic conditions and comprises estimated long term growth rates, weighted average cost of capital and estimated operating
# margins (Refer to Note 2.3.1).
# 9
#
# Cleaned Text from page 11:
# 2. Notes to the Interim Condensed Consolidated Financial Statements
# 2.1 BUSINESS COMBINATIONS
# Acquisitions during the year ended March 31, 2023
# Net Assets(1)
# 103
# 103
# Intangible assets :
# 274
# 274
# 30
# 30
# 24
# 24
#   Deferred tax liabilities on intangible assets
# (80)
# (80)
# 103
# 248
# 351
# 630
# 981
# (1) Includes cash and cash equivalents acquired of ₹ 26 crore.
# Fair value of trade receivables acquired, is ₹111 crore as of acquisition date and as of March 31, 2024 the amounts are fully collected.
# The purchase price is allocated to assets acquired and liabilities assumed based upon determination of fair values at the dates of acquisition as follows:
# The excess of the purchase consideration paid over the fair value of assets acquired has been attributed to goodwill. The primary items that generated this goodwill
# are the value of the acquired assembled workforce and estimated synergies, neither of which qualify as an intangible asset.
# Goodwill is not tax-deductible. Goodwill pertaining to these business combinations is allocated to operating segments as more fully described in Note 2.3.1.
# The purchase consideration of ₹981 crore includes cash of ₹936 crore and contingent consideration with an estimated fair value of ₹45 crore as on the date of
# At the acquisition date, the key inputs used in determination of the fair value of contingent consideration are the probabilities assigned towards achievement of
# financial targets and discount rate of 12.5%. As of March 31, 2024 the contingent consideration was fully paid.
# Additionally, these acquisitions have shareholder and employee retention bonus payable to the employees of the acquiree over three years, subject to their
# employee benefit expenses in the Interim Condensed Consolidated Statement of Statement of Profit or Loss over the period of service.
# Transaction costs that the Group incurs in connection with a business combination such as finder’s fees, legal fees, due diligence fees, and other professional and
# consulting fees are expensed as incurred. The transaction costs of ₹7 crore related to the acquisition have been included under administrative expenses in the
# Interim Condensed Consolidated Statement of Statement of Profit or Loss for the year ended March 31, 2023.
# During the year ended March 31, 2023 the Group, completed two business combinations to complement its digital offerings by acquiring 100% voting interests in:
# 1) oddity GmbH, oddity group services GmbH, oddity space GmbH, oddity jungle GmbH, oddity code GmbH and oddity waves GmbH (collectively known as
# oddity), a Germany-based digital marketing, experience, and commerce agencies on April 20, 2022.
# 2) BASE life science A/S, a consulting and technology firm in the life Science industry in Europe on September 1, 2022.
# These acquisitions are expected to strengthen the Group’s creative, branding and experience design capabilities and augment the Group’s life sciences expertise,
# Business combinations have been accounted for using the acquisition method under the provisions of Ind AS 103, Business Combinations.
# identifiable net assets. The choice of measurement basis is made on an acquisition-by-acquisition basis. Subsequent to acquisition, the carrying amount of non-
# The payments related to options issued by the Group over the non-controlling interests in its subsidiaries are accounted as financial liabilities and initially
# option at the date at which it becomes exercisable. In the event that the option expires unexercised, the liability is derecognized.
# Business combinations between entities under common control is accounted for at carrying value of the assets acquired and liabilities assumed in the Group's
# The purchase price in an acquisition is measured at the fair value of the assets transferred, equity instruments issued and liabilities incurred or assumed at the date
# of acquisition, which is the date on which control is transferred to the Group. The purchase price also includes the fair value of any contingent consideration.
# Identifiable assets acquired and liabilities and contingent liabilities assumed in a business combination are measured initially at their fair value on the date of
# in the Consolidated Statement of Profit and Loss.
# 10
#
# Cleaned Text from page 12:
# On April 18, 2024, Infosys Germany GmBH wholly owned step down subsidiary of Infosys Limited entered into a definitive agreement to acquire 100% of the
# equity share capital in in-tech Holding GmbH, leading provider of Engineering R&D services headquartered in Germany, for a consideration including earn-outs
# amounting up to EUR 450 million (approximately ₹4,045 crore), subject to customary closing adjustments.
# On January 11, 2024, Infosys Limited entered into a definitive agreement to acquire 100% of the equity share capital in InSemi Technology Services Private
# Limited, a semiconductor design services company headquartered in India, for a consideration including earn-outs, and management incentives and retention
# bonuses totaling up to ₹280 crore (approximately $34 million), subject to customary closing adjustments.
# 11
#
# Cleaned Text from page 13:
# 2.2 PROPERTY, PLANT AND EQUIPMENT
# Buildings (1)
# 22-25 years
# Plant and machinery (1)(2)
# 5 years
# 5 years
# Computer equipment (1)
# 3-5 years
# Furniture and fixtures (1)
# 5 years
# Vehicles(1)
# 5 years
# (2) Includes Solar plant with a useful life of 25 years
# The changes in the carrying value of property, plant and equipment for the three months ended March 31, 2024 are as follows:
# (1)
# Gross carrying value as at January 1, 2024
#           1,432         11,498          3,305          1,510          8,497               2,308                1,456                           45                     30,051
#                —              287             140               33             345                    54                     35                           —                          894
#                —                —             (16)              (14)           (224)                  (34)                   (37)                           —                        (325)
#                —              (15)               (1)                (1)               (7)                    (2)                     (7)                           —                          (33)
# Gross carrying value as at March 31, 2024
#           1,432         11,770          3,428          1,528          8,611               2,326                1,447                           45                     30,587
# Accumulated depreciation as at January 1, 2024
#                —         (4,814)        (2,584)         (1,253)        (6,267)             (1,807)              (1,131)                         (42)                   (17,898)
#                —            (111)             (63)              (32)           (336)                  (58)                   (46)                           —                        (646)
#                —                —               16               14             219                    26                     34                           —                          309
#                —                  4                 1                 2                 4                      2                       5                           —                            18
# Accumulated depreciation as at March 31, 2024
#                —         (4,921)        (2,630)         (1,269)        (6,380)             (1,837)              (1,138)                         (42)                   (18,217)
# Carrying value as at January 1, 2024
#           1,432           6,684             721             257          2,230                  501                   325                             3                     12,153
# Carrying value as at March 31, 2024
#           1,432           6,849             798             259          2,231                  489                   309                             3                     12,370
# The changes in the carrying value of property, plant and equipment for the three months ended March 31, 2023 were as follows:
# (1)
# Gross carrying value as at January 1, 2023
#           1,431         11,530          3,368          1,466          8,895               2,450                1,353                           44                     30,537
#                  2                29             109               55             494                  162                   103                             1                          955
#                (2)                —           (175)              (40)           (877)                (311)                   (13)                           —                     (1,418)
#                —                  3               —                 1                 7                      2                       2                           —                            15
# Gross carrying value as at March 31, 2023
#           1,431         11,562          3,302          1,482          8,519               2,303                1,445                           45                     30,089
# Accumulated depreciation as at January 1, 2023
#                —         (4,425)        (2,547)         (1,206)        (6,339)             (1,922)                 (992)                         (39)                   (17,470)
# ...
#                                     79                            92
# 2.21.2 McCamish Cybersecurity incident
# In November 2023, Infosys McCamish Systems (McCamish), a step-down subsidiary of Infosys Limited, experienced a cybersecurity incident resulting in the
# investigation of and response to the incident and remediation and restoration of impacted applications and systems. By December 31, 2023, McCamish, with
# external specialists’ assistance, substantially remediated and restored the affected applications and systems.
# Loss of contracted revenues and costs incurred with respect to remediations, restoration, communication efforts, investigative processes and analysis, legal
# services and others amounted to $38 million (approximately ₹316 crore).
# Actions taken by McCamish included investigative analysis conducted by a third-party cybersecurity firm to determine, among other things, whether and the
# costs including indemnities or damages/claims, which are indeterminable at this time.
# On March 6, 2024, a class action complaint was filed in the U.S. District Court for the Northern District of Georgia against McCamish . The complaint arises
# out of the cybersecurity incident at McCamish initially disclosed on November 3, 2023. The complaint was purportedly filed on behalf of all individuals within
# Apart from this, the Group is subject to legal proceedings and claims, which have arisen in the ordinary course of business. The Group’s management
# reasonably expects that such ordinary course legal actions, when ultimately concluded and determined, will not have a material and adverse effect on the
# 2.21.3 Legal Proceedings
# (1)  Capital contracts primarily comprises of commitments for infrastructure facilities and computer equipment.
# advances and deposits)(1)
# 35
#
# Cleaned Text from page 37:
# 2.22  RELATED PARTY TRANSACTIONS
# During the year ended March 31, 2024, the following are the changes in the subsidiaries.
# Uri Levine (retired as independent director effective April 19, 2023)
# Helene Auriol Potier (appointed as independent director effective May 26, 2023)
# Nitin Paranjpe (appointed as an additional and independent director effective January 1, 2024)
# Mohit Joshi (resigned as President effective March 11, 2023 and was on leave till June 9, 2023 which was his last date with the company)
# Nilanjan Roy (resigned as Chief Financial Officer of the Company effective March 31, 2024)
# Jayesh Sanghrajka (appointed as Chief Financial Officer effective April 1, 2024)
# 2024
# 2023
# 2024
# 2023
#                          30                          25                        113                        111
#                            5                            4                          17                          16
#                          35                          29                        130                        127
# On March 15, 2024, Infosys BPM Canada Inc, a Wholly-owned subsidiary of Infosys BPM Limited was dissolved.
# oddity Limited (Taipei) renamed as WongDoody limited  (Taipei) and oddity (Shanghai) Co., Ltd. renamed as WongDoody (Shanghai) Co.
# Infosys BPM Canada Inc, a Wholly-owned subsidiary of Infosys BPM Limited  was incorporated on  August 11, 2023.
# Refer to the Company's Annual Report for the year ended March 31, 2023 for the full names and other details of the Company's subsidiaries and
# (2) Does not include post-employment benefits and other long-term benefits based on actuarial valuation as these are done for the Company as a whole.
# (1) Total employee stock compensation expense for the three months ended March 31, 2024 and March 31, 2023 includes a charge of ₹17 crore and 8
# crore, respectively, towards key management personnel. For the year ended March 31, 2024 and March 31, 2023 includes a charge of ₹68 crore and
# ₹49 crore, respectively, towards key management personnel (Refer to Note 2.11).
# Year ended March 31,
# and executive officers (1)(2)
# Three months ended March 31,
# Infosys Americas Inc., (Infosys Americas) a Wholly-owned subsidiary of Infosys Limited is liquidated effective July 14, 2023.
# On September 29, 2023, oddity space GmbH, oddity waves GmbH, oddity jungle GmbH, oddity group services GmbH and oddity code GmbH
# On September 1, 2023 Infosys Ltd. acquired 100% of voting interests in Danske IT and Support Services India Private Limited (“Danske IT”).
# Danske IT renamed as Idunn Information Technology Private Limited from April 1, 2024.
# Kaleidoscope Prototyping LLC, a Wholly-owned subsidiary of Kaleidoscope Animations is liquidated effective November 1, 2023.
# On November 24, 2023 Stater Participations B.V (Wholly-owned subsidiary of Stater N.V) merged with Stater N.V and Stater Belgium N.V./S.A
# X18AO
# 36
#
# Cleaned Text from page 38:
# 2.23
# Services (1)*
# Retail (2) Communic
# ation (3)
# Energy,
# Utilities,
# Sciences (4)
# segments (5)
# Revenue from operations
#         10,010           5,429           4,666            5,068                 5,589           3,316           2,762           1,083              37,923
#        10,818          5,537          4,411            4,825                 5,078          2,989          2,681          1,102              37,441
#           6,042           2,591           3,033            2,717                 3,656           1,995           1,639              652              22,325
#          6,161          2,869          2,613            2,614                 3,248          1,734          1,514             701              21,454
#           2,027              974              823               920                    852              518              491              209                6,814
#          2,057          1,034             840               909                    928             505             462             254                6,989
# Segment operating income
#           1,941           1,864              810            1,431                 1,081              803              632              222                8,784
#          2,600          1,634             958            1,302                    902             750             705             147                8,998
#                1,163
#                1,121
# Other income, net (Refer to Note 2.17)
#                2,729
#                   671
#                   110
#                     82
# Profit before tax
#              10,240
#                8,466
# Income tax expense
#                2,265
#                   2,332
# Net Profit
#                7,975
#                6,134
#                1,163
#                   1,121
# Three months ended March 31, 2024 and March 31, 2023:
# Business segment revenue information is collated based on individual customers invoiced or in relation to which the revenue is otherwise recognized.
# Ind AS 108, Operating segments, establishes standards for the way that public business enterprises report information about operating segments and related disclosures
# about products and services, geographic areas, and major customers. The Group's operations predominantly relate to providing end-to-end business solutions to enable
# various performance indicators by business segments. Accordingly, information has been presented along business segments. The accounting principles used in the
# preparation of the financial statements are consistently applied to record revenue and expenditure in individual segments, and are as set out in the accounting policies.
# Business segments of the Group are primarily enterprises in Financial Services and Insurance, enterprises in Manufacturing, enterprises in Retail, Consumer Packaged
# Goods and Logistics, enterprises in the Energy, Utilities, Resources and Services, enterprises in Communication, Telecom OEM and Media, enterprises in Hi-Tech,
# businesses in India, Japan, China, Infosys Public Services & other enterprises in Public Services.
# Revenue and identifiable operating expenses in relation to segments are categorized based on items that are individually identifiable to that segment. Revenue for 'all other
# segments' represents revenue generated by Infosys Public services and revenue generated from customers located in India, Japan and China and other enterprises in Public
# services. Allocated expenses of segments include expenses incurred for rendering services from the Group's offshore software development centers and on-site expenses,
# which are categorized in relation to the associated efforts of the segment. Certain expenses such as depreciation and amortization, which form a significant component of
# total expenses, are not specifically allocable to specific segments as the underlying assets are used interchangeably. The Management believes that it is not practical to
# provide segment disclosures relating to those costs and expenses, and accordingly these expenses are separately disclosed as "unallocated" and adjusted against the total
# income of the Group.
# Assets and liabilities used in the Group's business are not identified to any of the reportable segments, as these are used interchangeably between segments. The
# Management believes that it is currently not practicable to provide segment disclosures relating to total assets and liabilities since a meaningful segregation of the available
# Disclosure of revenue by geographic locations is given in note 2.16 Revenue from operations.
# X19AOX18AO
# 37
#
# Cleaned Text from page 39:
# Services (1)*
# Retail (2) Communic
# ation (3)
# Energy,
# Utilities,
# Sciences (4)
# segments (5)
# Revenue from operations
#         42,158         22,504         17,991          20,035               22,298         12,411         11,515           4,758            153,670
#        43,763        21,204        18,086          18,539               19,035        11,867        10,085          4,188            146,767
#         24,782         11,704         11,071          10,838               14,596           7,232           6,716           2,938              89,877
#        24,990        10,892        11,101            9,923               12,493          6,959          5,834          2,801              84,993
#           8,052           3,918           3,232            3,674                 3,505           2,026           1,901           1,060              27,368
#          7,930          3,916          3,226            3,461                 3,429          1,949          1,685          1,048              26,644
# Segment operating income
#           9,324           6,882           3,688            5,523                 4,197           3,153           2,898              760              36,425
#        10,843          6,396          3,759            5,155                 3,113          2,959          2,566             339              35,130
#                4,678
#                4,225
# Other income, net (Refer to Note 2.17)
#                4,711
#                2,701
#                   470
#                   284
# Profit before tax
#              35,988
#              33,322
# Income tax expense
#                9,740
#                   9,214
# Net Profit
#              26,248
#              24,108
# Depreciation and amortization expense
#                4,678
#                4,225
# (1) Financial Services include enterprises in Financial Services and Insurance
# (2)  Retail includes enterprises in Retail, Consumer Packaged Goods and Logistics
# (3) Communication includes enterprises in Communication, Telecom OEM and Media
# (4)  Life Sciences includes enterprises in Life sciences and Health care
# (5)  Others include operating segments of businesses in India, Japan, China, Infosys Public Services & other enterprises in Public Services
# * Includes impact on account of McCamish cybersecurity incident. Refer note 2.21.3.
# No client individually accounted for more than 10% of the revenues for the three months and year ended March 31, 2024 and March 31, 2023, respectively.
# Year ended March 31, 2024 and March 31, 2023:
# 38
#
# Cleaned Text from page 40:
# 2.24  FUNCTION WISE CLASSIFICATION OF CONDENSED CONSOLIDATED STATEMENT OF PROFIT AND LOSS
# 2024
# 2023
# 2024
# 2023
# Revenue from operations
# 2.16
#                      37,923                      37,441                  153,670                  146,767
#                      26,748                      26,011                  107,413                  102,353
# Gross profit
#                      11,175                      11,430                    46,257                    44,414
#                        1,735                        1,659                      6,973                      6,249
#                        1,819                        1,894                      7,537                      7,260
#                        3,554                        3,553                    14,510                    13,509
# Operating profit
#                        7,621                        7,877                    31,747                    30,905
# Other income, net
# 2.17
#                        2,729                           671                      4,711                      2,701
#                           110                             82                         470                         284
# Profit before tax
#                      10,240                        8,466                    35,988                    33,322
# Tax expense:
# 2.15
#                        1,173                        2,260                      8,390                      9,287
# 2.15
#                        1,092                             72                      1,350                          (73)
# Profit for the period
#                        7,975                        6,134                    26,248                    24,108
# Other comprehensive income
# Items that will not be reclassified subsequently to profit or loss
# Remeasurement of the net defined benefit liability/asset, net
#                             26                             25                         120                             8
# Equity instruments through other comprehensive income, net
#                            (12)                            (15)
#                           19                            (7)
#                             14                             10                         139                             1
# Items that will be reclassified subsequently to profit or loss
# Fair value changes on derivatives designated as cash flow hedge, net
#                             28                             36                           11                            (7)
#                          (231)
#                             61                         226                         776
# Fair value changes on  investments, net
#                             37                             42                         144                        (256)
#                          (166)
#                           139                         381                         513
# Total other comprehensive income / (loss), net of tax
#                          (152)
#                           149                         520                         514
# Total comprehensive income for the period
#                        7,823                        6,283                    26,768                    24,622
# Profit attributable to:
#                        7,969                        6,128                    26,233                    24,095
#                               6                               6                           15                           13
#                        7,975                        6,134                    26,248                    24,108
# Total comprehensive income attributable to:
#                        7,821                        6,276                    26,754                    24,598
#                               2                               7                           14                           24
#                        7,823                        6,283                    26,768                    24,622
# April 18, 2024
#  Year ended March 31,
#  Three months ended March 31,
# X20AO
# 39

# %% [markdown]
# # Step 2

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=200)

page_chunks = {}

for page, text in pdf_text.items():
  chunks = text_splitter.split_text(text)
  page_chunks[page] = chunks

for page, chunks in page_chunks.items():
  print(f"Text chunks from page{page}:")
  for i, chunk in enumerate(chunks, start=1):
    print(f"Chunk[{i}:\n{chunk}\n")
# Out:
# Text chunks from page1:
# Chunk[1:
# Index
# Page No.
# Condensed Consolidated Balance Sheet ……………………………………………………………………………………
# 1
# Condensed Consolidated Statement of Profit and Loss ………………………………………………………………………
# 2
# Condensed Consolidated Statement of Changes in Equity …………………………………………………………………
# 3
# Condensed Consolidated Statement of Cash Flows …………………………………………………………………………
# 5
# Overview and Notes to the Interim Condensed Consolidated Financial Statements
# 1. Overview
# 1.1 Company overview ……………………………………………………………………………………………………
# 7
# 1.2 Basis of preparation of financial statements …………………………………………………………………………
# 7
# 1.3 Basis of consolidation …………………………………………………………………………………………………
# 7
# 1.4 Use of estimates and judgments ………………………………………………………………………………………
# 7
# 1.5 Critical accounting estimates and judgments…………………………………………………………………………
# 8
# 2. Notes to the Interim Condensed Consolidated Financial Statements
# 2.1 Business Combinations ………………………………………………………………………………………………
# 10
# 2.2 Property, plant and equipment ………………………………………………………………………………………
# 12
#
# Chunk[2:
# 2.1 Business Combinations ………………………………………………………………………………………………
# 10
# 2.2 Property, plant and equipment ………………………………………………………………………………………
# 12
# 2.3 Goodwill and other intangible assets…………………………………………………………………………………
# 14
# 2.4 Investments ……………………………………………………………………………………………………………
# 15
# 2.5 Loans …………………………………………………………………………………………………………………
# 16
# 2.6 Other financial assets …………………………………………………………………………………………………
# 16
# 2.7 Trade receivables ……………………………………………………………………………………………………
# 16
# 2.8 Cash and cash equivalents ……………………………………………………………………………………………
# 17
# 2.9 Other assets ……………………………………………………………………………………………………………
# 17
# 2.10 Financial instruments ………………………………………………………………………………………………
# 18
# 2.11 Equity ………………………………………………………………………………………………………………
# 22
# 2.12 Other financial liabilities ……………………………………………………………………………………………
# 25
# 2.13 Other liabilities ………………………………………………………………………………………………………
# 25
# 2.14 Provisions ……………………………………………………………………………………………………………
# 26
# 2.15 Income taxes …………………………………………………………………………………………………………
# 27
#
# Chunk[3:
# 25
# 2.13 Other liabilities ………………………………………………………………………………………………………
# 25
# 2.14 Provisions ……………………………………………………………………………………………………………
# 26
# 2.15 Income taxes …………………………………………………………………………………………………………
# 27
# 2.16 Revenue from operations ……………………………………………………………………………………………
# 28
# 2.17 Other income, net ……………………………………………………………………………………………………
# 30
# 2.18 Expenses ……………………………………………………………………………………………………………
# 31
# 2.19 Leases ………………………………………………………………………………………………………………
# 32
# 2.20 Basic and diluted shares used in computing earnings per equity share ……………………………………………
# 34
# 2.21 Contingent liabilities and commitments  ……………………………………………………………………………
# 34
# 2.22 Related party transactions ……………………………………………………………………………………………
# 36
# 2.23 Segment reporting ……………………………………………………………………………………………………
# 37
# 2.24 Function wise classification of Condensed Consolidated Statement of Profit and Loss ……………………………
# 39
# INFOSYS LIMITED AND SUBSIDIARIES
# Condensed Consolidated Financial Statements under
# Indian Accounting Standards (Ind AS)
#
# Chunk[4:
# 39
# INFOSYS LIMITED AND SUBSIDIARIES
# Condensed Consolidated Financial Statements under
# Indian Accounting Standards (Ind AS)
# for the three months and year ended March 31, 2024
#
# Text chunks from page2:
# Chunk[1:
# INFOSYS LIMITED AND SUBSIDIARIES
# (In ₹ crore )
# Condensed Consolidated Balance Sheets as at
# Note No.
# March 31, 2024
# March 31, 2023
# ASSETS
# Non-current assets
# Property, plant and equipment
# 2.2
#                               12,370                                13,346
# Right-of-use assets
# 2.19
#                                 6,552                                  6,882
# Capital work-in-progress
#                                    293                                     288
# Goodwill
# 2.3
#                                 7,303                                  7,248
# Other intangible assets
#                                 1,397                                  1,749
# Financial assets
# Investments
# 2.4
#                               11,708                                12,569
# Loans
# 2.5
#                                      34                                       39
# Other financial assets
# 2.6
#                                 3,105                                  2,798
# Deferred tax assets (net)
#
# Chunk[2:
# Other financial assets
# 2.6
#                                 3,105                                  2,798
# Deferred tax assets (net)
#                                    454                                  1,245
# Income tax assets (net)
#                                 3,045                                  6,453
# Other non-current assets
# 2.9
#                                 2,121                                  2,318
# Total non-current assets
#                               48,382                                54,935
# Current assets
# Financial assets
# Investments
# 2.4
#                               12,915                                  6,909
# Trade receivables
# 2.7
#                               30,193                                25,424
# Cash and cash equivalents
# 2.8
#                               14,786                                12,173
# Loans
# 2.5
#                                    248                                     289
# Other financial assets
# 2.6
#
# Chunk[3:
# 2.8
#                               14,786                                12,173
# Loans
# 2.5
#                                    248                                     289
# Other financial assets
# 2.6
#                               12,085                                11,604
# Income tax assets (net)
#                                 6,397                                         6
# Other current assets
# 2.9
#                               12,808                                14,476
# Total current assets
#                               89,432                                70,881
# Total assets
#                             137,814                              125,816
# EQUITY AND LIABILITIES
# Equity
# 2.11
#                                 2,071                                  2,069
# Other equity
#                               86,045                                73,338
# Total equity attributable to equity holders of the Company
#
# Chunk[4:
# Other equity
#                               86,045                                73,338
# Total equity attributable to equity holders of the Company
#                               88,116                                75,407
# Non-controlling interests
#                                    345                                     388
# Total equity
#                               88,461                                75,795
# Liabilities
# Non-current liabilities
# Financial Liabilities
# Lease liabilities
# 2.19
#                                 6,400                                  7,057
# Other financial liabilities
# 2.12
#                                 2,130                                  2,058
# Deferred tax liabilities (net)
#                                 1,794                                  1,220
# Other non-current liabilities
# 2.13
#                                    235                                     500
# Total non-current liabilities
#
# Chunk[5:
# Other non-current liabilities
# 2.13
#                                    235                                     500
# Total non-current liabilities
#                               10,559                                10,835
# Current liabilities
# Financial Liabilities
# Lease liabilities
# 2.19
#                                 1,959                                  1,242
# Trade payables
#                                 3,956                                  3,865
# Other financial liabilities
# 2.12
#                               16,959                                18,558
# Other current liabilities
# 2.13
#                               10,539                                10,830
# Provisions
# 2.14
#                                 1,796                                  1,307
# Income tax liabilities (net)
#                                 3,585                                  3,384
# Total current liabilities
#                               38,794                                39,186
#
# Chunk[6:
# 3,585                                  3,384
# Total current liabilities
#                               38,794                                39,186
# Total equity and liabilities
#                             137,814                              125,816
# The accompanying notes form an integral part of the interim condensed consolidated financial statements
# As per our report of even date attached
# for Deloitte Haskins & Sells LLP
# for and on behalf of the Board of Directors of Infosys Limited
# Chartered Accountants
# Firm’s Registration No :
# 117366W/ W-100018
# Sanjiv V. Pilgaonkar
# D. Sundaram
# Salil Parekh
# Bobby Parikh
# Partner
# Lead Independent Director
# Chief Executive Officer
# Director
# Membership No. 039826
# and Managing Director
# Bengaluru
# Jayesh Sanghrajka
# A.G.S. Manikantha
# April 18, 2024
# Chief Financial Officer
# Company Secretary
# Equity share capital
# 1
#
# Text chunks from page3:
# Chunk[1:
# INFOSYS LIMITED AND SUBSIDIARIES
# (In ₹ crore, except equity share and per equity share data)
# Note No.
# 2024
# 2023
# 2024
# 2023
# Revenue from operations
# 2.16
#                             37,923                             37,441                           153,670                           146,767
# Other income, net
# 2.17
#                               2,729                                  671                               4,711                               2,701
# Total income
#                             40,652                             38,112                           158,381                           149,468
# Expenses
# Employee benefit expenses
# 2.18
#                             20,393                             20,311                             82,620                             78,359
# Cost of technical sub-contractors
#                               2,967                               3,116                             12,232                             14,062
# Travel expenses
#
# Chunk[2:
# Cost of technical sub-contractors
#                               2,967                               3,116                             12,232                             14,062
# Travel expenses
#                                  471                                  426                               1,759                               1,525
# Cost of software packages and others
# 2.18
#                               3,687                               2,886                             13,515                             10,902
# Communication expenses
#                                  147                                  171                                  677                                  713
# Consultancy and professional charges
#                                  489                                  387                               1,726                               1,684
# Depreciation and amortization expenses
#
# Chunk[3:
# 489                                  387                               1,726                               1,684
# Depreciation and amortization expenses
#                               1,163                               1,121                               4,678                               4,225
# Finance cost
#                                  110                                    82                                  470                                  284
# Other expenses
# 2.18
#                                  985                               1,146                               4,716                               4,392
# Total expenses
#                             30,412                             29,646                           122,393                           116,146
# Profit before tax
#                             10,240                               8,466                             35,988                             33,322
# Tax expense:
# Current tax
#
# Chunk[4:
# Profit before tax
#                             10,240                               8,466                             35,988                             33,322
# Tax expense:
# Current tax
# 2.15
#                               1,173                               2,260                               8,390                               9,287
# Deferred tax
# 2.15
#                               1,092                                    72                               1,350                                  (73)
# Profit for the period
#                               7,975                               6,134                             26,248                             24,108
# Other comprehensive income
# Items that will not be reclassified subsequently to profit or loss
# Remeasurement of the net defined benefit liability/asset, net
#                                    26                                    25                                  120                                      8
#
# Chunk[5:
# 26                                    25                                  120                                      8
# Equity instruments through other comprehensive income, net
#                                  (12)                                  (15)                                    19                                    (7)
#                                    14                                    10                                  139                                      1
# Items that will be reclassified subsequently to profit or loss
# Fair value changes on derivatives designated as cash flow hedge, net
#                                    28                                    36                                    11                                    (7)
#                                (231)                                    61                                  226                                  776
# Fair value changes on investments, net
#
# Chunk[6:
# (231)                                    61                                  226                                  776
# Fair value changes on investments, net
#                                    37                                    42                                  144                                (256)
#                                (166)                                  139                                  381                                  513
# Total other comprehensive income /(loss), net of tax
#                                (152)                                  149                                  520                                  514
# Total comprehensive income for the period
#                               7,823                               6,283                             26,768                             24,622
# Profit attributable to:
# Owners of the Company
#
# Chunk[7:
# 7,823                               6,283                             26,768                             24,622
# Profit attributable to:
# Owners of the Company
#                               7,969                               6,128                             26,233                             24,095
# Non-controlling interests
#                                      6                                      6                                    15                                    13
#                               7,975                               6,134                             26,248                             24,108
# Total comprehensive income attributable to:
# Owners of the Company
#                               7,821                               6,276                             26,754                             24,598
# Non-controlling interests
#
# Chunk[8:
# Owners of the Company
#                               7,821                               6,276                             26,754                             24,598
# Non-controlling interests
#                                      2                                      7                                    14                                    24
#                               7,823                               6,283                             26,768                             24,622
# Earnings per equity share
# Equity shares of par value ₹5/- each
# Basic (in ₹ per share)
#                               19.25                               14.79                               63.39                               57.63
# Diluted (in ₹ per share)
#                               19.22                               14.77                               63.29                               57.54
# Basic (in shares)
# 2.20
#
# Chunk[9:
# Diluted (in ₹ per share)
#                               19.22                               14.77                               63.29                               57.54
# Basic (in shares)
# 2.20
#                 4,139,432,133                 4,144,013,195                 4,138,568,090                 4,180,897,857
# Diluted (in shares)
# 2.20
#                 4,145,052,370                 4,149,555,426                 4,144,680,425                 4,187,731,070
# The accompanying notes form an integral part of the interim condensed consolidated financial statements
# As per our report of even date attached
# for Deloitte Haskins & Sells LLP
# for and on behalf of the Board of Directors of Infosys Limited
# Chartered Accountants
# Firm’s Registration No :
# 117366W/ W-100018
# Sanjiv V. Pilgaonkar
# D. Sundaram
# Salil Parekh
# Bobby Parikh
# Partner
# Lead Independent Director
# Chief Executive Officer
# Director
# Membership No. 039826
# and Managing Director
# Bengaluru
# Jayesh Sanghrajka
# A.G.S. Manikantha
# April 18, 2024
#
# Chunk[10:
# Salil Parekh
# Bobby Parikh
# Partner
# Lead Independent Director
# Chief Executive Officer
# Director
# Membership No. 039826
# and Managing Director
# Bengaluru
# Jayesh Sanghrajka
# A.G.S. Manikantha
# April 18, 2024
# Chief Financial Officer
# Company Secretary
# Condensed Consolidated Statement of Profit and Loss for the
# Exchange differences on translation of foreign operations
# Weighted average equity shares used in computing earnings per equity share
# Year ended March 31,
# Three months ended March 31,
# 2
#
# Text chunks from page4:
# Chunk[1:
# INFOSYS LIMITED AND SUBSIDIARIES
# Condensed Consolidated Statement of Changes in Equity
# (In ₹ crore)
# Particulars
# Capital
# reserve
# Capital
# redemption
# reserve
# Securities
# Premium
# Retained
# earnings
# General
# reserve
# Share
# Options
# Outstanding
# Account
# Special
# Economic
# Zone Re-
# investment
# reserve (2)
# Other
# reserves (3)
# Equity
# instruments
# through other
# comprehensive
# income
# Exchange
# differences on
# translating the
# financial
# statements of a
# foreign operation
# Effective
# portion of
# Cash Flow
# Hedges
# Other items of
# other
# comprehensive
# income / (loss)
# Balance as at April 1, 2022
#            2,098                 54               139              200         61,313           1,061                606           8,339                16
#                     254                      1,560                       2                    (292)
#             75,350               386          75,736
# Impact on adoption of amendment to Ind AS 37#
#
# Chunk[2:
# 254                      1,560                       2                    (292)
#             75,350               386          75,736
# Impact on adoption of amendment to Ind AS 37#
#                 —                 —                 —                —              (19)                —                  —                —                —
#                       —                            —                     —                       —                   (19)
#                 —                (19)
#            2,098                 54               139              200         61,294           1,061                606           8,339                16
#                     254                      1,560                       2                    (292)
#             75,331               386          75,717
# Changes in equity for the year ended March 31, 2023
# Profit for the period
#
# Chunk[3:
# 75,331               386          75,717
# Changes in equity for the year ended March 31, 2023
# Profit for the period
#                 —                 —                 —                —         24,095                —                  —                —                —
#                       —                            —                     —                       —             24,095                 13          24,108
# Remeasurement of the net defined benefit liability/asset, net*
#                 —                 —                 —                —                —                —                  —                —                —
#                       —                            —                     —                         8                      8                 —                   8
# Equity instruments through other comprehensive income, net*
#
# Chunk[4:
# Equity instruments through other comprehensive income, net*
#                 —                 —                 —                —                —                —                  —                —                —
#                        (7)                            —                     —                       —                     (7)
#                 —                  (7)
# Fair value changes on derivatives designated as cash flow hedge, net*
#                 —                 —                 —                —                —                —                  —                —                —
#                       —                            —                     (7)                       —                     (7)
#                 —                  (7)
# Exchange differences on translation of foreign operations
#                 —                 —                 —                —                —                —                  —                —                —
#
# Chunk[5:
# —                 —                 —                —                —                —                  —                —                —
#                       —                         765                     —                       —                  765                 11               776
# Fair value changes on investments, net*
#                 —                 —                 —                —                —                —                  —                —                —
#                       —                            —                     —                    (256)                 (256)
#                 —              (256)
# Total Comprehensive income for the period
#                 —                 —                 —                —         24,095                —                  —                —                —
#                        (7)
#                         765                     (7)                    (248)
#
# Chunk[6:
# (7)
#                         765                     (7)                    (248)
#             24,598                 24          24,622
# Shares issued on exercise of employee stock options (Refer to Note
# 2.11)
#                   1                 —                 —                34                —                —                  —                —                —
#                       —                            —                     —                       —                    35                 —                 35
# Employee stock compensation expense (Refer to Note 2.11)
#                 —                 —                 —                —                —                —                514                —                —
#                       —                            —                     —                       —                  514                 —               514
# Transferred on account of options not exercised
#
# Chunk[7:
# Transferred on account of options not exercised
#                 —                 —                 —                —                —                  2                   (2)                —                —
#                       —                            —                     —                       —                    —                 —                 —
# Buyback of equity shares (Refer to Note 2.11) **
#                (30)                 —                 —            (340)       (11,096)                —                  —                —                —
#                       —                            —                     —                       —            (11,466)
#                 —         (11,466)
# Transaction costs relating to buyback*
#                 —                 —                 —              (19)                (5)                —                  —                —                —
#
# Chunk[8:
# —                 —                 —              (19)                (5)                —                  —                —                —
#                       —                            —                     —                       —                   (24)
#                 —                (24)
# Amount transferred to capital redemption reserve upon buyback
#                 —                 —                 30                —              (21)                (9)
#                  —                —                —
#                       —                            —                     —                       —                    —                 —                 —
# Transferred to Special Economic Zone Re-investment reserve
#                 —                 —                 —                —         (3,139)                —                  —           3,139                —
#
# Chunk[9:
# —                 —                 —                —         (3,139)                —                  —           3,139                —
#                       —                            —                     —                       —                    —                 —                 —
# Transfer to legal reserve
#                 —                 —                 —                —                (3)                —                  —                —                  3
#                       —                            —                     —                       —                    —                 —                 —
# Transferred on account of exercise of stock options (Refer to note
# 2.11)
#                 —                 —                 —              291                —                —               (291)                —                —
#
# Chunk[10:
# 2.11)
#                 —                 —                 —              291                —                —               (291)                —                —
#                       —                            —                     —                       —                    —                 —                 —
# Income tax benefit arising on exercise of stock options
#                 —                 —                 —                —                —                —                  51                —                —
#                       —                            —                     —                       —                    51                 —                 51
# Dividends (1)
#                 —                 —                 —                —       (13,632)                —                  —                —                —
#                       —                            —                     —                       —            (13,632)
#
# Chunk[11:
# —                            —                     —                       —            (13,632)
#                 —         (13,632)
# Dividends paid to non controlling interest of subsidiary
#                 —                 —                 —                —                —                —                  —                —                —
#                       —                            —                     —                       —                    —                (22)                (22)
# Transferred from Special Economic Zone Re-investment reserve on
# utilization
#                 —                 —                 —                —           1,464                —                  —         (1,464)                —
#                       —                            —                     —                       —                    —                 —                 —
# Balance as at March 31, 2023
#
# Chunk[12:
# —                            —                     —                       —                    —                 —                 —
# Balance as at March 31, 2023
#            2,069                 54               169              166         58,957           1,054                878         10,014                19
#                     247                      2,325                     (5)                    (540)
#             75,407               388          75,795
# OTHER EQUITY
# Reserves & Surplus
# Equity
# Share
# capital (1)
# Total equity
# attributable to
# equity holders
# of the
# Company
# Other comprehensive income
# Non-
# controlling
# interest
# Total equity
# 3
#
# Text chunks from page5:
# Chunk[1:
# Condensed Consolidated Statement of Changes in Equity (contd.)
# (In ₹ crore)
# Particulars
# Capital
# reserve
# Capital
# redemption
# reserve
# Securities
# Premium
# Retained
# earnings
# General
# reserve
# Share
# Options
# Outstanding
# Account
# Special
# Economic
# Zone Re-
# investment
# reserve (2)
# Other
# reserves (3)
# Equity
# instruments
# through other
# comprehensive
# income
# Exchange
# differences on
# translating the
# financial
# statements of a
# foreign operation
# Effective
# portion of
# Cash Flow
# Hedges
# Other items of
# other
# comprehensive
# income / (loss)
# Balance as at April 1, 2023
#            2,069                 54               169              166         58,957           1,054                878         10,014                19
#                     247                      2,325                     (5)                    (540)
#             75,407               388          75,795
# Changes in equity for the year ended March 31, 2024
# Profit for the period
#
# Chunk[2:
# 75,407               388          75,795
# Changes in equity for the year ended March 31, 2024
# Profit for the period
#                 —                 —                 —                —         26,233                —                  —                —                —
#                       —                            —                     —                       —             26,233                 15          26,248
# Remeasurement of the net defined benefit liability/asset, net*
#                 —                 —                 —                —                —                —                  —                —                —
#                       —                            —                     —                     120                  120                 —               120
# Equity instruments through other comprehensive income, net*
#
# Chunk[3:
# Equity instruments through other comprehensive income, net*
#                 —                 —                 —                —                —                —                  —                —                —
#                       19                            —                     —                       —                    19                 —                 19
# Fair value changes on derivatives designated as cash flow hedge, net*
#                 —                 —                 —                —                —                —                  —                —                —
#                       —                            —                     11                       —                    11                 —                 11
# Exchange differences on translation of foreign operations
#                 —                 —                 —                —                —                —                  —                —                —
#
# Chunk[4:
# —                 —                 —                —                —                —                  —                —                —
#                       —                         227                     —                       —                  227                  (1)
#               226
# Fair value changes on investments, net*
#                 —                 —                 —                —                —                —                  —                —                —
#                       —                            —                     —                     144                  144                 —               144
# Total Comprehensive income for the period
#                 —                 —                 —                —         26,233                —                  —                —                —
#
# Chunk[5:
# Total Comprehensive income for the period
#                 —                 —                 —                —         26,233                —                  —                —                —
#                       19                         227                     11                     264             26,754                 14          26,768
# Shares issued on exercise of employee stock options (Refer to Note
# 2.11)
#                   2                 —                 —                  3                —                —                  —                —                —
#                       —                            —                     —                       —                      5                 —                   5
# Employee stock compensation expense (Refer to Note 2.11)
#                 —                 —                 —                —                —                —                639                —                —
#
# Chunk[6:
# —                 —                 —                —                —                —                639                —                —
#                       —                            —                     —                       —                  639                 —               639
# Transferred on account of exercise of stock options (Refer to note
# 2.11)
#                 —                 —                 —              447                —                —               (447)                —                —
#                       —                            —                     —                       —                    —                 —                 —
# Transferred on account of options not exercised
#                 —                 —                 —                —                —              160               (160)                —                —
#
# Chunk[7:
# —                 —                 —                —                —              160               (160)                —                —
#                       —                            —                     —                       —                    —                 —                 —
# Income tax benefit arising on exercise of stock options
#                 —                 —                 —                —                —                —                    3                —                —
#                       —                            —                     —                       —                      3                 —                   3
# Transfer to legal reserve
#                 —                 —                 —                —                (3)                —                  —                —                  3
#
# Chunk[8:
# Transfer to legal reserve
#                 —                 —                 —                —                (3)                —                  —                —                  3
#                       —                            —                     —                       —                    —                 —                 —
# Dividends (1)
#                 —                 —                 —                —       (14,692)                —                  —                —                —
#                       —                            —                     —                       —            (14,692)
#                 —         (14,692)
# Dividends paid to non controlling interest of subsidiary
#                 —                 —                 —                —                —                —                  —                —                —
#
# Chunk[9:
# —                 —                 —                —                —                —                  —                —                —
#                       —                            —                     —                       —                    —                (39)                (39)
# Buyback of shares pertaining to non controlling interest of subsidiary
#                 —                 —                 —                —                —                —                  —                —                —
#                       —                            —                     —                       —                    —                (18)                (18)
# Transferred to Special Economic Zone Re-investment reserve
#                 —                 —                 —                —         (2,957)                —                  —           2,957                —
#
# Chunk[10:
# —                 —                 —                —         (2,957)                —                  —           2,957                —
#                       —                            —                     —                       —                    —                 —                 —
# Transferred from Special Economic Zone Re-investment reserve on
# utilization
#                 —                 —                 —                —              867                —                  —            (867)                —
#                       —                            —                     —                       —                    —                 —                 —
# Balance as at March 31, 2024
#            2,071                 54               169              616         68,405           1,214                913         12,104                22
#                     266                      2,552                       6                    (276)
#
# Chunk[11:
# 266                      2,552                       6                    (276)
#             88,116               345          88,461
# * Net of tax
# ** Including tax on buyback of ₹2,166 crore for the year ended March 31, 2023.
# #  Impact on account of adoption of amendment to Ind AS 37 Provisions, Contingent Liabilities and Contingents Assets
# (1) Net of treasury shares
# The accompanying notes form an integral part of the interim condensed consolidated financial statements.
# As per our report of even date attached
# for Deloitte Haskins & Sells LLP
# for and on behalf of the Board of Directors of Infosys Limited
# Chartered Accountants
# Firm’s Registration No :
# 117366W/ W-100018
# Sanjiv V. Pilgaonkar
# D. Sundaram
# Salil Parekh
# Bobby Parikh
# Partner
# Lead Independent Director
# Chief Executive Officer
# Director
# Membership No. 039826
# and Managing Director
# Bengaluru
# Jayesh Sanghrajka
# A.G.S. Manikantha
# April 18, 2024
# Chief Financial Officer
# Company Secretary
# Reserves & Surplus
#
# Chunk[12:
# Chief Executive Officer
# Director
# Membership No. 039826
# and Managing Director
# Bengaluru
# Jayesh Sanghrajka
# A.G.S. Manikantha
# April 18, 2024
# Chief Financial Officer
# Company Secretary
# Reserves & Surplus
# OTHER EQUITY
# (3) Under the Swiss Code of Obligation, few subsidiaries of Infosys Consulting are required to appropriate a certain percentage of the annual profit to legal reserve which may be used only to cover losses or for measures designed to sustain the Company through difficult times, to prevent unemployment or to
# mitigate its consequences.
# Equity
# Share
# capital (1)
# Total equity
# attributable to
# equity holders
# of the
# Company
# Other comprehensive income
# Non-
# controlling
# interest
# Total equity
#
# Chunk[13:
# mitigate its consequences.
# Equity
# Share
# capital (1)
# Total equity
# attributable to
# equity holders
# of the
# Company
# Other comprehensive income
# Non-
# controlling
# interest
# Total equity
# (2) The Special Economic Zone Re-investment Reserve has been created out of the profit of eligible SEZ units in terms of the provisions of Sec 10AA(1)(ii) of Income Tax Act, 1961. The reserve should be utilized by the Group for acquiring new plant and machinery for the purpose of its business in the terms of the
# Sec 10AA(2) of the Income Tax Act, 1961.
# 4
#
# Text chunks from page6:
# Chunk[1:
# INFOSYS LIMITED AND SUBSIDIARIES
# Condensed Consolidated Statement of Cash Flows
# Accounting policy
# (In ₹ crore)
# Particulars
# Note No.
# 2024
# 2023
# Cash flow from operating activities
# Profit for the period
#                              26,248                                   24,108
# Income tax expense
# 2.15
#                                9,740                                     9,214
# Depreciation and amortization
#                                4,678                                     4,225
#                               (2,067)                                   (1,817)
# Finance cost
#                                   470                                        284
# Impairment loss recognized / (reversed) under expected credit loss model
#                                   121                                        283
# Exchange differences on translation of assets and liabilities, net
#                                     76                                        161
# Stock compensation expense
#
# Chunk[2:
# Exchange differences on translation of assets and liabilities, net
#                                     76                                        161
# Stock compensation expense
#                                   652                                        519
# Interest on income tax refund
#                               (1,934)                                          —
# Provision for post sale client support
#                                     75                                        120
# Other adjustments
#                                1,464                                        508
# Changes in assets and liabilities
# Trade receivables and unbilled revenue
#                               (2,667)                                   (7,076)
# Loans, other financial assets and other assets
#                               (1,172)                                   (3,108)
# Trade payables
#                                     91                                      (279)
#
# Chunk[3:
# (1,172)                                   (3,108)
# Trade payables
#                                     91                                      (279)
# Other financial liabilities, other liabilities and provisions
#                               (1,334)                                     4,119
# Cash generated from operations
#                              34,441                                   31,261
# Income taxes paid
#                               (9,231)                                   (8,794)
# Net cash generated by operating activities
#                              25,210                                   22,467
# Cash flows from investing activities
#                               (2,201)                                   (2,579)
# Deposits placed with corporation
#                                  (847)                                      (996)
# Redemption of deposits placed with Corporation
#
# Chunk[4:
# Deposits placed with corporation
#                                  (847)                                      (996)
# Redemption of deposits placed with Corporation
#                                   710                                        762
#                                1,768                                     1,525
# 2.1
#                                     —                                      (910)
# Payment of contingent consideration pertaining to acquisition of business
#                                  (101)                                        (60)
# Escrow and other deposits pertaining to Buyback
#                                     —                                      (483)
# Redemption of escrow and other deposits pertaining to Buyback
#                                     —                                        483
# Other receipts
#                                   128                                          71
# Payments to acquire Investments
# Liquid mutual fund units
#
# Chunk[5:
# Other receipts
#                                   128                                          71
# Payments to acquire Investments
# Liquid mutual fund units
#                             (66,191)                                 (70,631)
# Target maturity fund units
#                                     —                                      (400)
# Certificates of deposit
#                               (8,509)                                 (10,348)
# Commercial Papers
#                             (10,387)                                   (3,003)
# Non-convertible debentures
#                               (1,526)                                      (249)
# Tax free bonds and government bonds
#                                     —                                        (27)
# Government securities
#                                     —                                   (1,569)
# Other Investments
#                                    (14)                                        (20)
#
# Chunk[6:
# —                                   (1,569)
# Other Investments
#                                    (14)                                        (20)
# Proceeds on sale of Investments
# Tax free bonds and government bonds
#                                   150                                        221
# Liquid mutual funds units
#                              64,767                                   71,851
# Certificates of deposit
#                                9,205                                   10,404
# Commercial Papers
#                                6,479                                     2,298
# Non-convertible debentures
#                                1,230                                        470
# Government securities
#                                   304                                     1,882
# Equity and preference securities
#                                     26                                          99
#
# Chunk[7:
# 304                                     1,882
# Equity and preference securities
#                                     26                                          99
# Net cash generated / (used in) from investing activities
#                               (5,009)                                   (1,209)
# Cash flows are reported using the indirect method, whereby profit for the period is adjusted for the effects of transactions of a non-cash nature, any
# deferrals or accruals of past or future operating cash receipts or payments and item of income or expenses associated with investing or financing cash
# flows. The cash flows from operating, investing and financing activities of the Group are segregated. The Group considers all highly liquid investments
# that are readily convertible to known amounts of cash to be cash equivalents.
# Interest and dividend received
# Year ended March 31,
# Expenditure on property, plant and equipment and intangibles
#
# Chunk[8:
# that are readily convertible to known amounts of cash to be cash equivalents.
# Interest and dividend received
# Year ended March 31,
# Expenditure on property, plant and equipment and intangibles
# Adjustments to reconcile net profit to net cash provided by operating
# activities:
# Interest and dividend income
# Payment towards acquisition of business, net of cash acquired
# 5
#
# Text chunks from page7:
# Chunk[1:
# Cash flows from financing activities
# Payment of lease liabilities
#                               (2,024)                                   (1,231)
# Payment of dividends
# ...
#
# Chunk[5:
# Danske IT renamed as Idunn Information Technology Private Limited from April 1, 2024.
# Kaleidoscope Prototyping LLC, a Wholly-owned subsidiary of Kaleidoscope Animations is liquidated effective November 1, 2023.
# oddity  Code d.o.o  renamed as WongDoody d.o.o
# On November 24, 2023 Stater Participations B.V (Wholly-owned subsidiary of Stater N.V) merged with Stater N.V and Stater Belgium N.V./S.A
# which was formerly a wholly owned subsidiary of Stater Participations B.V. became a wholly owned subsidiary of Stater N.V.
# X18AO
# 36
#
# Text chunks from page38:
# Chunk[1:
# 2.23
# Business Segments
# (In ₹ crore)
# Particulars
# Financial
# Services (1)*
# Retail (2) Communic
# ation (3)
# Energy,
# Utilities,
# Resources
# and Services
# Manufacturing
# Hi-Tech
# Life
# Sciences (4)
# All other
# segments (5)
# Total
# Revenue from operations
#         10,010           5,429           4,666            5,068                 5,589           3,316           2,762           1,083              37,923
#        10,818          5,537          4,411            4,825                 5,078          2,989          2,681          1,102              37,441
# Identifiable operating expenses
#           6,042           2,591           3,033            2,717                 3,656           1,995           1,639              652              22,325
#          6,161          2,869          2,613            2,614                 3,248          1,734          1,514             701              21,454
# Allocated expenses
#
# Chunk[2:
# 6,161          2,869          2,613            2,614                 3,248          1,734          1,514             701              21,454
# Allocated expenses
#           2,027              974              823               920                    852              518              491              209                6,814
#          2,057          1,034             840               909                    928             505             462             254                6,989
# Segment operating income
#           1,941           1,864              810            1,431                 1,081              803              632              222                8,784
#          2,600          1,634             958            1,302                    902             750             705             147                8,998
# Unallocable expenses
#                1,163
#                1,121
# Other income, net (Refer to Note 2.17)
#                2,729
#                   671
# Finance cost
#
# Chunk[3:
# Unallocable expenses
#                1,163
#                1,121
# Other income, net (Refer to Note 2.17)
#                2,729
#                   671
# Finance cost
#                   110
#                     82
# Profit before tax
#              10,240
#                8,466
# Income tax expense
#                2,265
#                   2,332
# Net Profit
#                7,975
#                6,134
# Depreciation and amortization
#                1,163
#                   1,121
# Non-cash expenses other than depreciation and amortization
#                     —
#                     —
# Three months ended March 31, 2024 and March 31, 2023:
# Business segment revenue information is collated based on individual customers invoiced or in relation to which the revenue is otherwise recognized.
# SEGMENT REPORTING
# Ind AS 108, Operating segments, establishes standards for the way that public business enterprises report information about operating segments and related disclosures
#
# Chunk[4:
# SEGMENT REPORTING
# Ind AS 108, Operating segments, establishes standards for the way that public business enterprises report information about operating segments and related disclosures
# about products and services, geographic areas, and major customers. The Group's operations predominantly relate to providing end-to-end business solutions to enable
# clients to enhance business performance. The Chief Operating Decision Maker (CODM) evaluates the Group's performance and allocates resources based on an analysis of
# various performance indicators by business segments. Accordingly, information has been presented along business segments. The accounting principles used in the
# preparation of the financial statements are consistently applied to record revenue and expenditure in individual segments, and are as set out in the accounting policies.
#
# Chunk[5:
# preparation of the financial statements are consistently applied to record revenue and expenditure in individual segments, and are as set out in the accounting policies.
# Business segments of the Group are primarily enterprises in Financial Services and Insurance, enterprises in Manufacturing, enterprises in Retail, Consumer Packaged
# Goods and Logistics, enterprises in the Energy, Utilities, Resources and Services, enterprises in Communication, Telecom OEM and Media, enterprises in Hi-Tech,
# enterprises in Life Sciences and Healthcare and all other segments. The Financial services reportable segments has been aggregated to include the Financial Services
# operating segment and Finacle operating segment because of the similarity of the economic characteristics. All other segments represent the operating segments of
# businesses in India, Japan, China, Infosys Public Services & other enterprises in Public Services.
#
# Chunk[6:
# businesses in India, Japan, China, Infosys Public Services & other enterprises in Public Services.
# Revenue and identifiable operating expenses in relation to segments are categorized based on items that are individually identifiable to that segment. Revenue for 'all other
# segments' represents revenue generated by Infosys Public services and revenue generated from customers located in India, Japan and China and other enterprises in Public
# services. Allocated expenses of segments include expenses incurred for rendering services from the Group's offshore software development centers and on-site expenses,
# which are categorized in relation to the associated efforts of the segment. Certain expenses such as depreciation and amortization, which form a significant component of
# total expenses, are not specifically allocable to specific segments as the underlying assets are used interchangeably. The Management believes that it is not practical to
#
# Chunk[7:
# total expenses, are not specifically allocable to specific segments as the underlying assets are used interchangeably. The Management believes that it is not practical to
# provide segment disclosures relating to those costs and expenses, and accordingly these expenses are separately disclosed as "unallocated" and adjusted against the total
# income of the Group.
# Assets and liabilities used in the Group's business are not identified to any of the reportable segments, as these are used interchangeably between segments. The
# Management believes that it is currently not practicable to provide segment disclosures relating to total assets and liabilities since a meaningful segregation of the available
# data is onerous.
# Disclosure of revenue by geographic locations is given in note 2.16 Revenue from operations.
# X19AOX18AO
# 37
#
# Text chunks from page39:
# Chunk[1:
# (In ₹ crore)
# Particulars
# Financial
# Services (1)*
# Retail (2) Communic
# ation (3)
# Energy,
# Utilities,
# Resources
# and Services
# Manufacturing
# Hi-Tech
# Life
# Sciences (4)
# All other
# segments (5)
# Total
# Revenue from operations
#         42,158         22,504         17,991          20,035               22,298         12,411         11,515           4,758            153,670
#        43,763        21,204        18,086          18,539               19,035        11,867        10,085          4,188            146,767
# Identifiable operating expenses
#         24,782         11,704         11,071          10,838               14,596           7,232           6,716           2,938              89,877
#        24,990        10,892        11,101            9,923               12,493          6,959          5,834          2,801              84,993
# Allocated expenses
#
# Chunk[2:
# 24,990        10,892        11,101            9,923               12,493          6,959          5,834          2,801              84,993
# Allocated expenses
#           8,052           3,918           3,232            3,674                 3,505           2,026           1,901           1,060              27,368
#          7,930          3,916          3,226            3,461                 3,429          1,949          1,685          1,048              26,644
# Segment operating income
#           9,324           6,882           3,688            5,523                 4,197           3,153           2,898              760              36,425
#        10,843          6,396          3,759            5,155                 3,113          2,959          2,566             339              35,130
# Unallocable expenses
#                4,678
#                4,225
# Other income, net (Refer to Note 2.17)
#                4,711
#                2,701
# Finance cost
#                   470
#
# Chunk[3:
# Unallocable expenses
#                4,678
#                4,225
# Other income, net (Refer to Note 2.17)
#                4,711
#                2,701
# Finance cost
#                   470
#                   284
# Profit before tax
#              35,988
#              33,322
# Income tax expense
#                9,740
#                   9,214
# Net Profit
#              26,248
#              24,108
# Depreciation and amortization expense
#                4,678
#                4,225
# Non-cash expenses other than depreciation and amortization
#                     —
#                     —
# (1) Financial Services include enterprises in Financial Services and Insurance
# (2)  Retail includes enterprises in Retail, Consumer Packaged Goods and Logistics
# (3) Communication includes enterprises in Communication, Telecom OEM and Media
# (4)  Life Sciences includes enterprises in Life sciences and Health care
#
# Chunk[4:
# (3) Communication includes enterprises in Communication, Telecom OEM and Media
# (4)  Life Sciences includes enterprises in Life sciences and Health care
# (5)  Others include operating segments of businesses in India, Japan, China, Infosys Public Services & other enterprises in Public Services
# * Includes impact on account of McCamish cybersecurity incident. Refer note 2.21.3.
# Significant clients
# No client individually accounted for more than 10% of the revenues for the three months and year ended March 31, 2024 and March 31, 2023, respectively.
# Year ended March 31, 2024 and March 31, 2023:
# 38
#
# Text chunks from page40:
# Chunk[1:
# 2.24  FUNCTION WISE CLASSIFICATION OF CONDENSED CONSOLIDATED STATEMENT OF PROFIT AND LOSS
# (In ₹ crore)
# Particulars
# Note No.
# 2024
# 2023
# 2024
# 2023
# Revenue from operations
# 2.16
#                      37,923                      37,441                  153,670                  146,767
# Cost of Sales
#                      26,748                      26,011                  107,413                  102,353
# Gross profit
#                      11,175                      11,430                    46,257                    44,414
# Operating expenses
# Selling and marketing expenses
#                        1,735                        1,659                      6,973                      6,249
# General and administration expenses
#                        1,819                        1,894                      7,537                      7,260
# Total operating expenses
#                        3,554                        3,553                    14,510                    13,509
# Operating profit
#
# Chunk[2:
# Total operating expenses
#                        3,554                        3,553                    14,510                    13,509
# Operating profit
#                        7,621                        7,877                    31,747                    30,905
# Other income, net
# 2.17
#                        2,729                           671                      4,711                      2,701
# Finance cost
#                           110                             82                         470                         284
# Profit before tax
#                      10,240                        8,466                    35,988                    33,322
# Tax expense:
# Current tax
# 2.15
#                        1,173                        2,260                      8,390                      9,287
# Deferred tax
# 2.15
#                        1,092                             72                      1,350                          (73)
# Profit for the period
#
# Chunk[3:
# Deferred tax
# 2.15
#                        1,092                             72                      1,350                          (73)
# Profit for the period
#                        7,975                        6,134                    26,248                    24,108
# Other comprehensive income
# Items that will not be reclassified subsequently to profit or loss
# Remeasurement of the net defined benefit liability/asset, net
#                             26                             25                         120                             8
# Equity instruments through other comprehensive income, net
#                            (12)                            (15)
#                           19                            (7)
#                             14                             10                         139                             1
# Items that will be reclassified subsequently to profit or loss
# Fair value changes on derivatives designated as cash flow hedge, net
#
# Chunk[4:
# Items that will be reclassified subsequently to profit or loss
# Fair value changes on derivatives designated as cash flow hedge, net
#                             28                             36                           11                            (7)
# Exchange differences on translation of foreign operations
#                          (231)
#                             61                         226                         776
# Fair value changes on  investments, net
#                             37                             42                         144                        (256)
#                          (166)
#                           139                         381                         513
# Total other comprehensive income / (loss), net of tax
#                          (152)
#                           149                         520                         514
# Total comprehensive income for the period
#
# Chunk[5:
# (152)
#                           149                         520                         514
# Total comprehensive income for the period
#                        7,823                        6,283                    26,768                    24,622
# Profit attributable to:
# Owners of the Company
#                        7,969                        6,128                    26,233                    24,095
# Non-controlling interests
#                               6                               6                           15                           13
#                        7,975                        6,134                    26,248                    24,108
# Total comprehensive income attributable to:
# Owners of the Company
#                        7,821                        6,276                    26,754                    24,598
# Non-controlling interests
#
# Chunk[6:
# Owners of the Company
#                        7,821                        6,276                    26,754                    24,598
# Non-controlling interests
#                               2                               7                           14                           24
#                        7,823                        6,283                    26,768                    24,622
# for and on behalf of the Board of Directors of Infosys Limited
# D. Sundaram
# Salil Parekh
# Bobby Parikh
# Lead Independent Director
# Chief Executive Officer
# Director
# and Managing Director
# Bengaluru
# Jayesh Sanghrajka
# A.G.S. Manikantha
# April 18, 2024
# Chief Financial Officer
# Company Secretary
#  Year ended March 31,
#  Three months ended March 31,
# X20AO
# 39

# %%
import nltk
nltk.download('stopwords')

import nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
from rake_nltk import Rake

rake = Rake()

page_phrases = {}

for page, text in pdf_text.items():
  rake.extract_keywords_from_text(text)
  phrases = rake.get_ranked_phrases()
  page_phrases[page] = phrases

chunk_phrases = {}
for page, chunks in page_chunks.items():
    for chunk_number, chunk in enumerate(chunks, start=1):
        rake.extract_keywords_from_text(chunk)
        phrases = rake.get_ranked_phrases()
        chunk_phrases[(page, chunk_number)] = phrases

for (page, chunk_number), phrases in chunk_phrases.items():
  print(f"Key phrases from page {page}, chunk {chunk_number}:\n{phrases}\n")
# Out:
# Key phrases from page 1, chunk 1:
# ['condensed consolidated balance sheet …………………………………………………………………………………… 1 condensed consolidated statement', 'loss ……………………………………………………………………… 2 condensed consolidated statement', 'equity ………………………………………………………………… 3 condensed consolidated statement', 'interim condensed consolidated financial statements 1', 'interim condensed consolidated financial statements 2', '1 business combinations ……………………………………………………………………………………………… 10 2', '1 company overview …………………………………………………………………………………………………… 7 1', 'financial statements ………………………………………………………………………… 7 1', 'cash flows ………………………………………………………………………… 5 overview', 'consolidation ………………………………………………………………………………………………… 7 1', 'judgments ……………………………………………………………………………………… 7 1', 'judgments ………………………………………………………………………… 8 2', '5 critical accounting estimates', 'overview 1', 'equipment ……………………………………………………………………………………… 12', '2 property', '2 basis', '3 basis', 'index page', '4 use', 'estimates', 'profit', 'preparation', 'plant', 'notes', 'notes', 'changes']
#
# Key phrases from page 1, chunk 2:
# ['1 business combinations ……………………………………………………………………………………………… 10 2', '7 trade receivables …………………………………………………………………………………………………… 16 2', '10 financial instruments ……………………………………………………………………………………………… 18 2', '15 income taxes ………………………………………………………………………………………………………… 27', 'financial assets ………………………………………………………………………………………………… 16 2', '5 loans ………………………………………………………………………………………………………………… 16 2', '11 equity ……………………………………………………………………………………………………………… 22 2', 'intangible assets ………………………………………………………………………………… 14 2', '4 investments …………………………………………………………………………………………………………… 15 2', '14 provisions …………………………………………………………………………………………………………… 26 2', 'financial liabilities …………………………………………………………………………………………… 25 2', 'cash equivalents …………………………………………………………………………………………… 17 2', 'assets …………………………………………………………………………………………………………… 17 2', 'liabilities ……………………………………………………………………………………………………… 25 2', 'equipment ……………………………………………………………………………………… 12 2', '2 property', '8 cash', '2', '3 goodwill', '12', 'plant', '9', '6', '13']
#
# Key phrases from page 1, chunk 3:
# ['computing earnings per equity share …………………………………………… 34 2', '22 related party transactions …………………………………………………………………………………………… 36 2', '23 segment reporting …………………………………………………………………………………………………… 37 2', '15 income taxes ………………………………………………………………………………………………………… 27 2', 'loss …………………………… 39 infosys limited', '19 leases ……………………………………………………………………………………………………………… 32 2', '18 expenses …………………………………………………………………………………………………………… 31 2', '14 provisions …………………………………………………………………………………………………………… 26 2', 'subsidiaries condensed consolidated financial statements', 'commitments …………………………………………………………………………… 34 2', 'operations …………………………………………………………………………………………… 28 2', 'net …………………………………………………………………………………………………… 30 2', '24 function wise classification', 'liabilities ……………………………………………………………………………………………………… 25 2', 'condensed consolidated statement', '21 contingent liabilities', 'indian accounting standards', 'diluted shares used', '25 2', '20 basic', '16 revenue', 'income', 'profit', 'ind', '17', '13']
#
# Key phrases from page 1, chunk 4:
# ['subsidiaries condensed consolidated financial statements', 'year ended march 31', 'indian accounting standards', '39 infosys limited', 'three months', 'ind', '2024']
#
# Key phrases from page 2, chunk 1:
# ['progress 293 288 goodwill 2', '749 financial assets investments 2', 'condensed consolidated balance sheets', '798 deferred tax assets', 'financial assets 2', 'use assets 2', 'current assets property', '2023 assets non', '569 loans 2', '882 capital work', '5 34 39', 'intangible assets 1', '2024 march 31', 'equipment 2', '2 12', '105 2', 'march 31', '397 1', '₹ crore', 'infosys limited', '708 12', '6 3', '552 6', '4 11', '370 13', '346 right', '303 7', '3 7', '19 6', 'subsidiaries', 'plant', 'note', 'net', '248']
#
# Key phrases from page 2, chunk 2:
# ['935 current assets financial assets investments 2', '798 deferred tax assets', '245 income tax assets', '909 trade receivables 2', 'financial assets 2', 'financial assets 2', 'current assets 2', 'current assets 48', '173 loans 2', '5 248 289', 'cash equivalents 2', '318 total non', '9 2', '121 2', '105 2', '424 cash', '8 14', '786 12', '7 30', '454 1', '4 12', '382 54', '193 25', '915 6', '045 6', '6 3', 'non', '6', '3', 'net', 'net', '453']
#
# Key phrases from page 2, chunk 3:
# ['476 total current assets 89', '881 total assets 137', '604 income tax assets', '338 total equity attributable', 'current assets 2', 'financial assets 2', '5 248 289', '173 loans 2', 'liabilities equity 2', 'equity holders', 'equity 86', '816 equity', '11 2', '071 2', '9 12', '814 125', '808 14', '8 14', '786 12', '432 70', '085 11', '045 73', '6 12', '397 6', '2', '6', 'net', 'company', '069']
#
# Key phrases from page 2, chunk 4:
# ['controlling interests 345 388 total equity 88', 'current liabilities financial liabilities lease liabilities 2', '13 235 500 total non', '338 total equity attributable', '058 deferred tax liabilities', 'financial liabilities 2', 'current liabilities 2', '795 liabilities non', 'current liabilities', 'company 88', 'equity holders', 'equity 86', '130 2', '12 2', '407 non', '461 75', '400 7', '19 6', '116 75', '045 73', '794 1', 'non', '1', 'net', '220', '057']
#
# Key phrases from page 2, chunk 5:
# ['835 current liabilities financial liabilities lease liabilities 2', '384 total current liabilities 38', '13 235 500 total non', '307 income tax liabilities', 'financial liabilities 2', '242 trade payables 3', 'current liabilities 2', 'current liabilities 2', 'current liabilities 10', '830 provisions 2', '13 10', '956 3', '585 3', '559 10', '539 10', '959 18', '959 1', '796 1', '794 39', '19 1', '14 1', '12 16', 'non', '3', 'net', '865', '558', '186']
#
# Key phrases from page 2, chunk 6:
# ['sundaram salil parekh bobby parikh partner lead independent director chief executive officer director membership', '2024 chief financial officer company secretary equity share capital 1', 'infosys limited chartered accountants firm ’', 'managing director bengaluru jayesh sanghrajka', 'interim condensed consolidated financial statements', '384 total current liabilities 38', '186 total equity', 'manikantha april 18', 'even date attached', 'accompanying notes form', '100018 sanjiv v', 'liabilities 137', 'sells llp', 'integral part', 'deloitte haskins', '814 125', '794 39', '585 3', '3', 'w', 'report', 'registration', 'pilgaonkar', 'per', 'g', 'directors', 'board', 'behalf', '816', '117366w', '039826']
#
# Key phrases from page 3, chunk 1:
# ['468 expenses employee benefit expenses 2', '2024 2023 2024 2023 revenue', 'per equity share data', '701 total income 40', '062 travel expenses', 'except equity share', '729 671 4', 'operations 2', 'net 2', 'contractors 2', '711 2', '17 2', '₹ crore', 'technical sub', 'infosys limited', '967 3', '923 37', '670 146', '652 38', '620 78', '441 153', '393 20', '381 149', '359 cost', '311 82', '232 14', '18 20', '16 37', '116 12', '112 158', 'income', 'subsidiaries', 'note', '767']
#
# Key phrases from page 3, chunk 2:
# ['902 communication expenses 147 171 677 713 consultancy', '062 travel expenses 471 426 1', 'professional charges 489 387 1', 'amortization expenses', '759 1', '726 1', 'technical sub', 'software packages', 'others 2', 'contractors 2', '967 3', '886 13', '687 2', '684 depreciation', '515 10', '232 14', '18 3', '116 12', '525 cost', 'cost']
#
# Key phrases from page 3, chunk 3:
# ['225 finance cost 110 82 470 284', '392 total expenses 30', 'amortization expenses 1', '489 387 1', '18 985 1', '322 tax expense', 'expenses 2', '726 1', '163 1', 'tax 10', 'current tax', '988 33', '716 4', '684 depreciation', '678 4', '646 122', '466 35', '412 29', '393 116', '240 8', '146 profit', '146 4', '121 4']
#
# Key phrases from page 3, chunk 4:
# ['net 26 25 120 8', 'net defined benefit liability', '287 deferred tax 2', 'current tax 2', 'comprehensive income items', '322 tax expense', '092 72 1', '134 26', 'tax 10', '260 8', '240 8', '173 2', '15 1', '15 1', 'reclassified subsequently', 'period 7', 'loss remeasurement', '988 33', '975 6', '466 35', '390 9', '248 24', 'profit', 'profit', 'profit', 'asset', '73', '350', '108']
#
# Key phrases from page 3, chunk 5:
# ['26 25 120 8 equity instruments', '61 226 776 fair value changes', '14 10 139 1 items', 'loss fair value changes', 'net 28 36 11', 'cash flow hedge', 'reclassified subsequently', 'derivatives designated', 'comprehensive income', 'net', 'net', 'profit', 'investments', '7', '7', '231', '19', '15', '12']
#
# Key phrases from page 3, chunk 6:
# ['61 226 776 fair value changes', 'comprehensive income /( loss ), net', '149 520 514 total comprehensive income', 'net 37 42 144', '139 381 513 total', '622 profit attributable', 'period 7', '823 6', '768 24', '283 26', 'tax', 'owners', 'investments', 'company', '256', '231', '166', '152']
#
# Key phrases from page 3, chunk 7:
# ['controlling interests 6 6 15 13 7', '108 total comprehensive income attributable', '622 profit attributable', 'controlling interests', '975 6', '969 6', '823 6', '821 6', 'company 7', 'company 7', '768 24', '754 24', '598 non', '283 26', '276 26', '248 24', '233 24', '134 26', '128 26', '095 non', '7', 'owners', 'owners']
#
# Key phrases from page 3, chunk 8:
# ['622 earnings per equity share equity shares', 'controlling interests 2 7 14 24 7', 'par value ₹ 5 /-', '₹ per share', '₹ per share', 'company 7', '768 24', '754 24', '25 14', '22 14', 'shares', '823 6', '821 6', '79 63', '77 63', '63 diluted', '598 non', '39 57', '29 57', '283 26', '276 26', '2', '54 basic', 'basic', 'owners', '20', '19', '19']
#
# Key phrases from page 3, chunk 9:
# ['sundaram salil parekh bobby parikh partner lead independent director chief executive officer director membership', 'infosys limited chartered accountants firm ’', 'managing director bengaluru jayesh sanghrajka', 'interim condensed consolidated financial statements', 'manikantha april 18', 'even date attached', 'accompanying notes form', '100018 sanjiv v', '₹ per share', 'sells llp', 'integral part', 'deloitte haskins', '77 63', '54 basic', '426 4', '425 4', '370 4', '29 57', '22 14', '20 4', '20 4', '195 4', '133 4', '090 4', '857 diluted', 'per', 'diluted', 'w', 'shares', 'shares', 'report', 'registration', 'pilgaonkar', 'g', 'directors', 'board', 'behalf', '897', '731', '680', '568', '555', '432', '2024', '2', '2', '19', '187', '180', '149', '145', '144', '144', '139', '138', '117366w', '070', '052', '039826', '013']
#
# Key phrases from page 3, chunk 10:
# ['salil parekh bobby parikh partner lead independent director chief executive officer director membership', '2024 chief financial officer company secretary condensed consolidated statement', 'computing earnings per equity share year ended march 31', 'foreign operations weighted average equity shares used', 'three months ended march 31', 'managing director bengaluru jayesh sanghrajka', 'manikantha april 18', 'exchange differences', 'translation', 'profit', 'loss', 'g', '2', '039826']
#
# Key phrases from page 4, chunk 1:
# ['particulars capital reserve capital redemption reserve securities premium retained earnings general reserve share options outstanding account special economic zone', '098 54 139 200 61', 'investment reserve', 'subsidiaries condensed consolidated statement', 'foreign operation effective portion', '339 16 254 1', 'comprehensive income exchange differences', 'cash flow hedges', '061 606 8', '350 386 75', 'comprehensive income', 'april 1', '313 1', '₹ crore', 'infosys limited', 'financial statements', '736 impact', '560 2', '2022 2', 'equity instruments', '75', '2', 'equity', 'translating', 'reserves', 'loss', 'items', 'ind', 'changes', 'balance', 'amendment', 'adoption', '37', '3', '292']
#
# Key phrases from page 4, chunk 2:
# ['— — — — — — — —', '098 54 139 200 61', '— — — —', 'year ended march 31', '339 16 254 1', '061 606 8', '350 386 75', '331 386 75', '—', '254 1', '294 1', '736 impact', '717 changes', '2023 profit', '560 2', '560 2', '75', '75', '2', 'period', 'ind', 'equity', 'amendment', 'adoption', '37', '292', '292', '19', '19', '19']
#
# Key phrases from page 4, chunk 3:
# ['— — — — — — — — — — — — 8 8 — 8 equity instruments', '095 — — — — — — — — 24', 'period — — — — 24', 'year ended march 31', '095 13 24', 'net defined benefit liability', 'equity', '331 386 75', 'comprehensive income', '717 changes', '2023 profit', '108 remeasurement', 'net', 'net', '75', 'asset']
#
# Key phrases from page 4, chunk 4:
# ['foreign operations — — — — — — — — —', '— — — — — — — — — — —', '— — — — — — — — —', '— — —', 'fair value changes', 'cash flow hedge', '—', '—', '—', 'exchange differences', 'equity instruments', 'derivatives designated', 'comprehensive income', 'translation', 'net', 'net', '7', '7', '7', '7', '7', '7']
#
# Key phrases from page 4, chunk 5:
# ['— — — — — — — — — — 765 — — 765 11 776 fair value changes', '— — — — — — — — — — — —', 'period — — — — 24', '095 — — — —', '765', '—', 'total comprehensive income', 'net', 'investments', '7', '7', '256', '256', '256', '248']
#
# Key phrases from page 4, chunk 6:
# ['1 — — 34 — — — — — — — — — 35 — 35 employee stock compensation expense', '— — — — — — 514 — — — — — — 514 — 514 transferred', 'employee stock options', '622 shares issued', '598 24 24', 'note 2', 'note 2', '24', 'options', 'refer', 'refer', 'exercised', 'exercise', 'account', '765', '7', '7', '248', '11', '11']
#
# Key phrases from page 4, chunk 7:
# ['— — — — — — — — — buyback', '— — — — — — — —', 'exercised — — — — — 2', '— — — —', '— — —', '— —', 'transaction costs relating', '—', 'buyback', 'note 2', 'equity shares', '2', 'transferred', 'refer', 'options', 'account', '5', '466', '466', '340', '30', '19', '11', '11', '11', '11', '096', '**']
#
# Key phrases from page 4, chunk 8:
# ['— — — — — — — — — — transferred', 'capital redemption reserve upon buyback — — 30 —', '— — — — — — — —', 'investment reserve — — — —', '— — —', '— — 3', '139 —', 'special economic zone', 'amount transferred', '—', '3', '139', '9', '5', '24', '24', '21', '19']
#
# Key phrases from page 4, chunk 9:
# ['— — — 3 — — — — — — — transferred', '139 — — — — — — — — transfer', 'legal reserve — — — —', '— — — 291 — —', '— — — —', '— — 3', '— —', '139', '3', '3', 'stock options', 'note 2', '291', 'refer', 'exercise', 'account', '11']
#
# Key phrases from page 4, chunk 10:
# ['stock options — — — — — — 51 — — — — — — 51 — 51 dividends', '— — — — — — — — — income tax benefit arising', '— — — — — — — —', '— — — 291 — —', '— — — —', '291', 'exercise', '632', '632', '2', '13', '13', '11', '1']
#
# Key phrases from page 4, chunk 11:
# ['subsidiary — — — — — — — — — — — — — —', '— — — — — — — — balance', 'utilization — — — — 1', '— — — —', '464 — —', '—', 'special economic zone', 'non controlling interest', 'march 31', 'investment reserve', 'dividends paid', '1', '464', 'transferred', '632', '632', '22', '22', '2023', '13', '13']
#
# Key phrases from page 4, chunk 12:
# ['— — — — — — — balance', '069 54 169 166 58', 'controlling interest total equity 3', 'surplus equity share capital', '014 19 247 2', 'total equity attributable', 'comprehensive income non', '054 878 10', '407 388 75', 'equity reserves', 'equity holders', '2023 2', 'march 31', '957 1', '75', '1', 'company', '795', '540', '5', '325']
#
# Key phrases from page 5, chunk 1:
# ['particulars capital reserve capital redemption reserve securities premium retained earnings general reserve share options outstanding account special economic zone', '069 54 169 166 58', 'investment reserve', 'year ended march 31', 'foreign operation effective portion', '014 19 247 2', 'comprehensive income exchange differences', 'condensed consolidated statement', 'cash flow hedges', '054 878 10', '407 388 75', 'comprehensive income', '2023 2', '₹ crore', 'financial statements', 'contd .)', 'april 1', '957 1', '2024 profit', '795 changes', 'equity instruments', '2', '75', 'changes', 'equity', 'equity', 'translating', 'reserves', 'period', 'loss', 'items', 'balance', '540', '5', '325', '3']
#
# Key phrases from page 5, chunk 2:
# ['— — — — — — — — — — — — 120 120 — 120 equity instruments', '233 — — — — — — — — 26', 'period — — — — 26', 'year ended march 31', '233 15 26', 'net defined benefit liability', 'equity', '407 388 75', 'comprehensive income', '795 changes', '248 remeasurement', '2024 profit', 'net', 'net', '75', 'asset']
#
# Key phrases from page 5, chunk 3:
# ['— — — — — — — — — 19 — — — 19 — 19 fair value changes', '— — — — — — — — — — — 11 — 11 — 11 exchange differences', 'foreign operations — — — — — — — — —', 'cash flow hedge', 'equity instruments', 'derivatives designated', 'comprehensive income', 'translation', 'net', 'net']
#
# Key phrases from page 5, chunk 4:
# ['— — — — — — — — — — — — 144 144 — 144 total comprehensive income', '— — — — — — — — — — 227 — — 227', 'period — — — — 26', '233 — — — —', '226 fair value changes', 'net', 'investments', '1']
#
# Key phrases from page 5, chunk 5:
# ['2 — — 3 — — — — — — — — — 5 — 5 employee stock compensation expense', '— — — — — — 639 — —', '233 — — — — 19 227 11 264 26', 'period — — — — 26', 'employee stock options', '754 14 26', 'note 2', 'note 2', 'total comprehensive income', '768 shares issued', '11', '11', 'refer', 'refer', 'exercise']
#
# Key phrases from page 5, chunk 6:
# ['— — — — — — 639 — — — — — — 639 — 639 transferred', '— — — — — — — — — transferred', 'exercised — — — — — 160', '— — — 447 — —', '— —', 'note 2', '160', 'stock options', '447', 'options', 'refer', 'exercise', 'account', 'account', '11']
#
# Key phrases from page 5, chunk 7:
# ['stock options — — — — — — 3 — — — — — — 3 — 3 transfer', '— — — — — — — — — income tax benefit arising', '— — — — — 160', 'legal reserve — — — —', '— — — 3', '3', '160', 'exercise']
#
# Key phrases from page 5, chunk 8:
# ['— — — 3 — — — — — — — dividends', 'subsidiary — — — — — — — — —', '— — — — — — — —', 'legal reserve — — — —', '— — — —', 'non controlling interest', 'dividends paid', '—', '3', 'transfer', '692', '692', '692', '14', '14', '14', '1']
#
# Key phrases from page 5, chunk 9:
# ['subsidiary — — — — — — — — — — — — — —', '— — — — — — — — — — — — — —', 'investment reserve — — — —', '— — 2', '957 —', 'special economic zone', 'non controlling interest', 'shares pertaining', '2', '957', 'transferred', 'buyback', '39', '39', '18', '18']
#
# Key phrases from page 5, chunk 10:
# ['957 — — — — — — — — transferred', '— — — — — — — — balance', 'utilization — — — — 867 — —', '— — — —', '071 54 169 616 68', '— — 2', '104 22 266 2', 'special economic zone', '214 913 12', '957', '867', '2024 2', 'march 31', 'investment reserve', '552 6', '405 1', '2', '276']
#
# Key phrases from page 5, chunk 11:
# ['sundaram salil parekh bobby parikh partner lead independent director chief executive officer director membership', '2024 chief financial officer company secretary reserves', 'infosys limited chartered accountants firm ’', 'managing director bengaluru jayesh sanghrajka', 'interim condensed consolidated financial statements', 'year ended march 31', 'tax ** including tax', 'manikantha april 18', 'even date attached', 'accompanying notes form', '100018 sanjiv v', '116 345 88', '₹ 2', 'treasury shares', 'sells llp', 'integral part', 'deloitte haskins', 'contingents assets', 'contingent liabilities', '552 6', '37 provisions', '266 2', '166 crore', '88', 'w', 'surplus', 'report', 'registration', 'pilgaonkar', 'per', 'net', 'net', 'ind', 'impact', 'g', 'directors', 'buyback', 'board', 'behalf', 'amendment', 'adoption', 'account', '461', '276', '2023', '117366w', '1', '039826']
#
# Key phrases from page 5, chunk 12:
# ['2024 chief financial officer company secretary reserves', 'chief executive officer director membership', 'managing director bengaluru jayesh sanghrajka', 'controlling interest total equity', 'total equity attributable', 'manikantha april 18', 'comprehensive income non', 'equity share capital', 'equity holders', 'swiss code', 'prevent unemployment', 'measures designed', 'legal reserve', 'infosys consulting', 'difficult times', 'cover losses', 'certain percentage', 'annual profit', 'company', 'company', 'equity', 'used', 'sustain', 'surplus', 'subsidiaries', 'required', 'obligation', 'mitigate', 'may', 'g', 'consequences', 'appropriate', '3', '1', '039826']
#
# Key phrases from page 5, chunk 13:
# ['controlling interest total equity', 'total equity attributable', 'special economic zone', 'income tax act', 'income tax act', 'equity share capital', 'eligible sez units', 'comprehensive income non', 'acquiring new plant', '1 )( ii', 'equity holders', 'sec 10aa', 'sec 10aa', 'investment reserve', '1', 'reserve', 'utilized', 'terms', 'terms', 'purpose', 'provisions', 'profit', 'mitigate', 'machinery', 'group', 'created', 'consequences', 'company', 'business', '4', '2', '2', '1961', '1961']
#
# Key phrases from page 6, chunk 1:
# ['expected credit loss model 121 283 exchange differences', 'finance cost 470 284 impairment loss recognized', 'net 76 161 stock compensation expense', '108 income tax expense 2', 'subsidiaries condensed consolidated statement', 'cash flows accounting policy', '2024 2023 cash flow', 'operating activities profit', '₹ crore', 'period 26', 'particulars note', 'infosys limited', 'amortization 4', '740 9', '678 4', '248 24', '214 depreciation', '15 9', '2', 'translation', 'reversed', 'liabilities', 'assets', '817', '225', '1', '067']
#
# Key phrases from page 6, chunk 2:
# ['net 76 161 stock compensation expense 652 519 interest', 'post sale client support 75 120', 'trade payables 91', 'income tax refund', '464 508 changes', 'liabilities trade receivables', '— provision', 'unbilled revenue', 'exchange differences', 'adjustments 1', 'financial assets', 'liabilities', '1', '1', 'assets', 'assets', 'assets', 'translation', 'loans', '934', '7', '667', '3', '279', '2', '172', '108', '076']
#
# Key phrases from page 6, chunk 3:
# ['261 income taxes paid', 'trade payables 91', 'net cash generated', '467 cash flows', '119 cash generated', 'operating activities 25', 'investing activities', 'operations 34', 'deposits placed', 'deposits placed', '441 31', '210 22', 'financial liabilities', 'liabilities', 'redemption', 'provisions', 'corporation', 'corporation', '996', '9', '847', '8', '794', '579', '4', '334', '3', '279', '231', '201', '2', '2', '172', '108', '1', '1']
#
# Key phrases from page 6, chunk 4:
# ['acquire investments liquid mutual fund units', 'receipts 128 71 payments', 'corporation 710 762 1', 'contingent consideration pertaining', 'buyback — 483', '1 —', 'buyback —', '768 1', 'deposits pertaining', 'deposits pertaining', 'deposits placed', 'deposits placed', '525 2', 'corporation', '483', 'redemption', 'redemption', 'payment', 'escrow', 'escrow', 'business', 'acquisition', '996', '910', '847', '60', '101']
#
# Key phrases from page 6, chunk 5:
# ['acquire investments liquid mutual fund units', 'target maturity fund units —', 'receipts 128 71 payments', 'government securities —', 'government bonds —', 'tax free bonds', 'convertible debentures', 'commercial papers', 'investments', 'non', 'deposit', 'certificates', '8', '70', '66', '631', '569', '526', '509', '400', '387', '348', '3', '27', '249', '20', '191', '14', '10', '10', '1', '1', '003']
#
# Key phrases from page 6, chunk 6:
# ['government bonds 150 221 liquid mutual funds units 64', '230 470 government securities 304 1', 'preference securities 26 99', 'investments tax free bonds', '404 commercial papers 6', 'convertible debentures 1', 'deposit 9', '882 equity', '851 certificates', '767 71', '479 2', '298 non', '205 10', '1', 'investments', '—', 'sale', 'proceeds', '569', '20', '14']
#
# Key phrases from page 6, chunk 7:
# ['preference securities 26 99 net cash generated', 'dividend received year ended march 31', 'future operating cash receipts', 'highly liquid investments', 'financing cash flows', 'cash flows', 'cash flows', 'cash nature', 'cash equivalents', 'financing activities', 'whereby profit', 'reported using', 'readily convertible', 'known amounts', 'indirect method', 'expenses associated', '882 equity', 'group considers', '304 1', 'investing activities', 'cash', 'operating', 'group', '1', 'investing', 'investing', 'used', 'transactions', 'segregated', 'property', 'plant', 'period', 'payments', 'past', 'non', 'item', 'interest', 'intangibles', 'income', 'expenditure', 'equipment', 'effects', 'deferrals', 'adjusted', 'accruals', '5', '209', '009']
#
# Key phrases from page 6, chunk 8:
# ['dividend received year ended march 31', 'dividend income payment towards acquisition', 'reconcile net profit', 'cash acquired 5', 'net cash provided', 'cash equivalents', 'readily convertible', 'operating activities', 'known amounts', 'intangibles adjustments', 'net', 'cash', 'property', 'plant', 'interest', 'interest', 'expenditure', 'equipment', 'business']
#
# Key phrases from page 7, chunk 1:
# ['employee stock options 5 35', 'equity shares including transaction cost', '— shares issued', 'financing activities payment', 'non controlling interest', 'payment towards buyback', 'shares pertaining', 'controlling interest', 'lease liabilities', 'cash flows', 'payment', 'payment', 'non', 'buyback', 'buyback', 'tax', 'subsidiary', 'subsidiary', 'receipts', 'payments', 'exercise', 'dividends', 'dividend', '736', '692', '631', '479', '39', '231', '22', '2', '18', '14', '132', '13', '1', '024']
#
# Key phrases from page 7, chunk 2:
# ['equity shares including transaction cost', 'restricted cash balance 2', 'exchange rate changes', '173 supplementary information', 'net cash used', 'cash equivalents 2', 'period 2', 'period 2', 'net increase', 'cash equivalents', 'cash equivalents', 'cash equivalents', '472 cash', '138 cash', 'financing activities', '786 12', '173 17', '8 14', '8 12', 'cash', 'cash', '8', '17', 'tax', 'payments', 'end', 'effect', 'decrease', 'buyback', 'buyback', 'beginning', '84', '736', '697', '695', '504', '5', '499', '479', '437', '26', '11']
#
# Key phrases from page 7, chunk 3:
# ['sundaram salil parekh bobby parikh partner lead independent director chief executive officer director membership', '2024 chief financial officer company secretary 6', 'infosys limited chartered accountants firm ’', 'managing director bengaluru jayesh sanghrajka', 'interim condensed consolidated financial statements', 'restricted cash balance 2', 'manikantha april 18', 'even date attached', 'accompanying notes form', '173 supplementary information', '100018 sanjiv v', '8 348 362', 'period 2', '8 14', 'cash equivalents', 'sells llp', 'integral part', 'deloitte haskins', '786 12', 'cash', 'w', 'report', 'registration', 'pilgaonkar', 'per', 'g', 'end', 'directors', 'board', 'behalf', '117366w', '039826']
#
# Key phrases from page 8, chunk 1:
# ['interim condensed consolidated financial statements 1', "1 company overview infosys limited ('", 'public limited company incorporated', 'generating profitable returns', 'creating growth opportunities', 'infosys strategic objective', 'generation digital services', 'overview 1', 'infosys limited', 'subsidiaries overview', 'infosys together', 'infosys strategy', 'digital transformation', 'digital future', 'sustainable organization', 'remains relevant', 'registered office', 'provides consulting', 'hosur road', 'hereinafter referred', 'group ".', 'electronics city', 'controlled trusts', 'execute strategies', 'enable clients', 'company', 'company', 'infosys', 'subsidiaries', 'execute', 'clients', 'clients', 'technology', 'plan', 'outsourcing', 'notes', 'next', 'navigator', 'journey', 'investors', 'india', 'ideate', 'employees', 'domiciled', 'build', 'bengaluru', 'agenda']
#
# Key phrases from page 8, chunk 2:
# ['interim condensed consolidated financial statements', 'interim condensed consolidated financial statements', '34 interim financial reporting', 'new york stock exchange', 'public limited company incorporated', 'national stock exchange', 'certain financial instruments', 'representing equity shares', 'indian accounting standard', 'historical cost convention', 'american depositary shares', 'accrual basis except', 'financial statements', '2 basis', 'india limited', 'registered office', 'primary listings', 'nyse ).', 'hosur road', 'fair values', 'electronics city', 'bse ltd', 'bengaluru 560100', 'april 18', 'company ’', 'company', 'company', 'company', 'india', 'india', 'provisions', 'prepared', 'preparation', 'measured', 'listed', 'karnataka', 'issue', 'ind', 'group', 'domiciled', 'directors', 'compliance', 'board', 'approved', 'ads', '2024', '1']
#
# Key phrases from page 8, chunk 3:
# ['interim condensed consolidated financial statements', 'interim condensed consolidated financial statements', 'relevant amendment rules issued thereafter', 'year ended march 31', 'newly issued accounting standard', 'consolidated financial statements', 'certain financial instruments', 'related notes included', 'historical cost convention', 'consistently applied except', 'accrual basis except', 'indian accounting standards', 'financial statements', 'guidelines issued', 'existing accounting', 'accounting policies', 'section 133', 'sebi ).', 'rule 3', 'initially adopted', 'information required', 'fair values', 'exchange board', 'complete set', 'company ’', 'annual report', "act ')", "2013 ('", 'companies act', 'act read', 'rules', 'read', 'companies', 'securities', 'revision', 'reporting', 'provisions', 'prescribed', 'measured', 'india', 'ind', 'include', 'conjunction', 'accordingly', '2023', '2015']
#
# Key phrases from page 8, chunk 4:
# ['interim condensed consolidated financial statements comprise', 'audited condensed consolidated interim financial statements', 'material accounting policy information used', 'consolidation infosys consolidates entities', 'newly issued accounting standard', 'existing accounting standard requires', 'accounting policy hitherto', 'financial statements', 'previous quarters might', 'consistently applied except', 'date figures reported', 'accounting policies', 'figures reported', 'date figures', 'respective notes', 'nearest digits', 'initially adopted', 'always add', '3 basis', 'quarter figures', 'statement added', 'statement', 'quarter', 'year', 'year', 'use', 'taken', 'source', 'rounded', 'revision', 'preparation', 'owns', 'discussed', 'controls', 'change', '1']
#
# Key phrases from page 8, chunk 5:
# ['interim condensed consolidated financial statements comprise', 'transactions including unrealized gain', 'consolidation infosys consolidates entities', 'direct relevant activities', 'date control commences', 'date control ceases', 'financial statements', 'financial statements', 'control exists', 'group companies', 'group balances', 'controlled trusts', '3 basis', 'significantly affect', 'line basis', 'existing rights', 'variable returns', 'consolidated', 'consolidated', 'rights', 'line', 'affect', 'returns', 'returns', 'using', 'subsidiaries', 'subsidiaries', 'power', 'power', 'power', 'parent', 'owns', 'involvement', 'intra', 'give', 'exposed', 'entity', 'entity', 'entity', 'entity', 'demonstrated', 'controls', 'company', 'ability', 'ability', '1']
#
# Key phrases from page 8, chunk 6:
# ['interim condensed consolidated financial statements', 'transactions including unrealized gain', 'applying uniform accounting policies', 'eliminated upon consolidation', 'date control ceases', 'financial statements', 'financial statements', 'accounting policies', 'represent part', 'reported amounts', 'net profit', 'controlling interests', 'group companies', 'group balances', 'net assets', 'line basis', 'assumptions affect', '4 use', 'make estimates', 'consolidated', 'transactions', 'group', 'use', 'line', 'assumptions', 'assets', 'estimates', 'estimates', 'subsidiaries', 'requires', 'prepared', 'preparation', 'owned', 'non', 'management', 'loss', 'loss', 'liabilities', 'judgments', 'judgments', 'judgments', 'intra', 'indirectly', 'ind', 'excluded', 'directly', 'controlled', 'conformity', 'company', 'application', '1']
#
# Key phrases from page 8, chunk 7:
# ['require critical accounting estimates involving complex', 'interim condensed consolidated financial statements', 'interim condensed consolidated financial statements', 'actual results could differ', 'accounting estimates could change', 'management becomes aware', 'financial statements', 'accounting policies', 'accounting policies', 'reported amounts', 'reported amounts', 'circumstances surrounding', 'subjective judgments', 'contingent assets', 'assumptions affect', 'appropriate changes', 'estimates', 'estimates', 'estimates', 'estimates', 'estimates', 'judgments', 'assets', 'assumptions', 'assumptions', 'changes', 'changes', 'changes', 'use', 'revenues', 'reflected', 'period', 'period', 'period', 'period', 'note', 'made', 'liabilities', 'liabilities', 'judgements', 'expenses', 'disclosures', 'disclosed', 'date', 'application', 'application', '5', '1']
#
# Key phrases from page 8, chunk 8:
# ['interim condensed consolidated financial statements', 'interim condensed consolidated financial statements', 'reflected', 'period', 'notes', 'material', 'made', 'judgements', 'estimates', 'estimates', 'effects', 'disclosed', 'changes', 'changes', '7']
#
# Key phrases from page 9, chunk 1:
# ['distinct performance obligations involves significant judgment', 'identifies distinct performance obligations', '5 critical accounting estimates', 'distinct performance obligations', 'transfer multiple products', 'customers include promises', 'respective obligations', 'transaction price', 'legally enforceable', 'group ’', 'group assesses', 'benefit independently', 'services promised', 'revenue recognition', 'customer contracts', 'services', 'recognition', 'contracts', 'customer', 'customer', 'writing', 'revenues', 'perform', 'parties', 'parties', 'measurement', 'judgments', 'identification', 'determine', 'deliverables', 'deliverables', 'contract', 'contract', 'contract', 'contract', 'contract', 'contract', 'contract', 'considered', 'committed', 'approved', 'allocation', 'ability', '1']
#
# Key phrases from page 9, chunk 2:
# ['distinct performance obligations involves significant judgment', 'maintenance revenues requires judgment', 'fixed price maintenance revenue', 'fixed price maintenance contract', 'recognized ratably using', 'transaction price', 'recognized ratably', 'line basis', 'indefinite number', 'group ’', 'generally discrete', 'benefit independently', 'specified period', 'repetitive acts', 'completion method', 'services rendered', 'revenue', 'contract', 'contract', 'contract', 'repetitive', 'period', 'method', 'services', 'services', 'use', 'straight', 'recognize', 'promises', 'performed', 'percentage', 'pattern', 'nature', 'nature', 'fulfil', 'even', 'deliverables', 'deliverables', 'customer', 'customer', 'costs', 'benefits', 'based', 'allocation', 'ability']
#
# Key phrases from page 9, chunk 3:
# ['measure progress towards completion', 'customers includes subcontractor services', 'costs involves significant judgment', 'certain integrated services arrangements', 'party vendor products', 'party vendor equipment', 'latest available information', 'completion method requires', 'estimated total efforts', 'completion method', 'total efforts', 'recorded net', 'direct relationship', 'costs expended', 'costs expended', 'changes based', 'assessed throughout', 'actual efforts', 'price contracts', 'group uses', 'services', 'arrangements', 'efforts', 'costs', 'costs', 'contracts', 'group', 'group', 'used', 'use', 'types', 'third', 'third', 'software', 'sales', 'revenue', 'reflect', 'proportion', 'promises', 'productivity', 'period', 'percentage', 'percentage', 'nature', 'input', 'incurred', 'fixed', 'estimation', 'determine', 'deliverables', 'date', 'contract', 'contract', 'agent', 'acting', 'accounting']
#
# Key phrases from page 9, chunk 4:
# ['losses become probable based', 'group first evaluates whether', 'group considers whether', 'party vendor products', 'estimated losses', 'determine whether', 'specified goods', 'specified goods', 'specified goods', 'primarily responsible', 'pricing discretion', 'obtains control', 'inventory risk', 'incomplete contracts', 'income taxes', 'estimated efforts', 'recorded net', 'group', 'group', 'vendor', 'recorded', 'types', 'transferred', 'transaction', 'third', 'therefore', 'services', 'services', 'services', 'services', 'sales', 'revenue', 'provisions', 'provide', 'promise', 'principal', 'principal', 'period', 'gross', 'fulfilling', 'factors', 'customer', 'customer', 'costs', 'costs', 'controls', 'contract', 'complete', 'b', 'arrangements', 'agent', 'agent', 'acting', 'acting']
#
# Key phrases from page 9, chunk 5:
# ['company also files tax returns', 'temporary differences become deductible', 'deferred income tax liabilities', 'deferred income tax assets', 'deferred income tax assets', 'deferred income tax assets', 'two major tax jurisdictions', 'projected future taxable income', 'future taxable income', 'future taxable income', 'uncertain tax positions', 'tax planning strategies', 'historical taxable income', 'including amount expected', 'management considers whether', 'income taxes', 'income taxes', 'overseas jurisdictions', 'management considers', 'united states', 'ultimate realization', 'significant judgments', 'scheduled reversals', 'dependent upon', 'though', 'recovered', 'realized', 'realizability', 'provision', 'projections', 'portion', 'periods', 'paid', 'making', 'level', 'involved', 'india', 'group', 'generation', 'determining', 'costs', 'contract', 'complete', 'based', 'b', 'assessment', 'assessing']
#
# Key phrases from page 9, chunk 6:
# ['deferred income tax assets considered realizable', 'deferred income tax assets', 'intangible assets business combinations', 'tax planning strategies', 'identifiable intangible assets', 'historical taxable income', 'future taxable income', 'future taxable income', 'carry forward period', 'identifiable assets', 'business combinations', 'business combinations', 'notes 2', 'near term', 'management believes', 'fair valued', 'fair value', 'contingent consideration', '15 ).', 'using ind', 'deductible differences', 'contingent liabilities', '103 requires', 'liabilities', 'ind', 'deductible', '103', 'valuations', 'refer', 'reduced', 'reduced', 'realize', 'projections', 'periods', 'order', 'making', 'level', 'however', 'group', 'estimates', 'could', 'c', 'benefits', 'based', 'assessment', 'ascertain', 'amount', 'acquiree', 'accounted']
#
# Key phrases from page 9, chunk 7:
# ['external valuation experts', 'expected useful life', 'expected residual value', 'useful lives', 'residual values', 'significant proportion', 'periodic depreciation', 'option arrangements', 'note 2', 'intangible assets', 'information available', 'identifiable assets', 'fair valued', 'equipment represent', 'deemed reasonable', 'asset ’', 'asset base', 'acquisition date', '1 ).', 'fair value', 'equipment property', 'contingent liabilities', 'contingent consideration', 'life', 'value', 'value', 'property', 'liabilities', 'consideration', 'valuations', 'respect', 'required', 'refer', 'plant', 'plant', 'order', 'measurements', 'management', 'made', 'group', 'group', 'expectations', 'estimates', 'estimate', 'end', 'determining', 'determining', 'derived', 'conducted', 'charge', 'based', 'based', 'assumptions', 'ascertain', 'acquiree']
#
# Key phrases from page 9, chunk 8:
# ['expected residual value', 'financial year end', 'expected useful life', 'residual values', 'useful lives', 'reviewed periodically', 'note 2', 'may impact', 'historical experience', 'future events', '2 ).', 'similar assets', 'asset ’', 'end', 'life', 'life', 'lives', 'assets', 'asset', 'well', 'time', 'technology', 'refer', 'management', 'including', 'group', 'estimate', 'determining', 'determined', 'changes', 'based', 'anticipation', 'acquired', '8']
#
# Key phrases from page 10, chunk 1:
# ['comprises estimated long term growth rates', 'fair value less cost', 'estimated operating margins', 'weighted average cost', 'internal management purposes', 'current economic conditions', 'cash generating unit', 'cash flow projections', 'recoverable amount', 'recoverable amount', 'prepared based', 'note 2', 'lowest level', 'key assumptions', 'determined based', 'carrying amount', 'annual basis', '1 ).', 'impairment test', 'goodwill goodwill', 'value', 'less', 'goodwill', 'goodwill', 'impairment', 'impairment', 'whenever', 'use', 'tested', 'synergies', 'sell', 'represent', 'refer', 'monitored', 'indication', 'higher', 'groups', 'e', 'cgus', 'cgus', 'cgus', 'cgu', 'capital', 'benefit', 'allocated', 'acquisition', '9', '3']
#
# Key phrases from page 11, chunk 1:
# ['carrying amount fair value adjustments purchase price allocated net assets', 'interim condensed consolidated financial statements 2', '1 business combinations accounting policy acquisitions', '24 24 deferred tax liabilities', 'year ended march 31', '274 274 vendor relationships', '103 intangible assets', '30 30 brand', 'total 103 248', 'intangible assets', '₹ crore', 'customer contracts', 'component acquiree', '2', '1', 'relationships', '103', 'notes', '80', '80', '2023']
#
# Key phrases from page 11, chunk 2:
# ['total 103 248 351 goodwill 630 total purchase price 981', 'liabilities assumed based upon determination', 'purchase price', 'purchase consideration paid', 'deferred tax liabilities', '₹ 26 crore', '₹ 111 crore', 'trade receivables acquired', 'acquired assembled workforce', 'cash equivalents acquired', 'assets acquired', 'assets acquired', 'includes cash', 'primary items', 'march 31', 'intangible assets', 'intangible asset', 'goodwill', 'goodwill', 'fully collected', 'fair values', 'estimated synergies', 'fair value', 'fair value', 'acquisition date', 'value', 'acquisition', 'qualify', 'neither', 'generated', 'follows', 'excess', 'dates', 'attributed', 'amounts', 'allocated', '80', '80', '2024', '1']
#
# Key phrases from page 11, chunk 3:
# ['₹ 981 crore includes cash', 'probabilities assigned towards achievement', 'employee retention bonus payable', '₹ 936 crore', '₹ 45 crore', 'key inputs used', 'acquired assembled workforce', 'estimated fair value', 'fair value', 'estimated synergies', 'three years', 'purchase consideration', 'operating segments', 'note 2', 'march 31', 'intangible asset', 'fully paid', 'fully described', 'financial targets', 'discount rate', 'contingent consideration', 'contingent consideration', 'contingent consideration', 'business combinations', '5 %.', 'goodwill pertaining', 'acquisition date', 'value', 'goodwill', 'date', 'acquisition', 'tax', 'subject', 'shareholder', 'qualify', 'neither', 'employees', 'determination', 'deductible', 'allocated', 'additionally', 'acquisitions', 'acquiree', '3', '2024', '12', '1']
#
# Key phrases from page 11, chunk 4:
# ['₹ 7 crore related', 'year ended march 31', 'interim condensed consolidated statement', 'interim condensed consolidated statement', 'employee retention bonus payable', 'employee benefit expenses', 'due diligence fees', 'retention bonus', 'administrative expenses', 'transaction costs', 'transaction costs', 'three years', 'respective years', 'legal fees', 'group incurs', 'group along', 'finder ’', 'financial targets', 'continuous employment', 'consulting fees', 'business combination', 'statement', 'statement', 'fees', 'subject', 'shareholder', 'service', 'recognized', 'profit', 'profit', 'professional', 'period', 'performance', 'loss', 'loss', 'incurred', 'included', 'expensed', 'employees', 'connection', 'additionally', 'acquisitions', 'acquisition', 'acquiree', 'achievement', '2023']
#
# Key phrases from page 11, chunk 5:
# ['year ended march 31', 'year ended march 31', 'completed two business combinations', 'cloud based industry solutions', 'interim condensed consolidated statement', 'oddity group services gmbh', 'life science industry', 'based digital marketing', 'life sciences expertise', 'base life science', 'oddity waves gmbh', 'oddity space gmbh', 'oddity jungle gmbh', 'oddity code gmbh', 'digital transformation capabilities', 'presence across europe', 'experience design capabilities', 'oddity gmbh', 'oddity ),', 'digital offerings', 'group ’', 'group ’', 'voting interests', 'technology firm', 'commerce agencies', 'collectively known', 'april 20', 'acquiring 100', 'september 1', 'statement', 'group', 'experience', 'europe', '1', 'strengthen', 'scales', 'profit', 'loss', 'germany', 'expected', 'expand', 'creative', 'consulting', 'complement', 'branding', 'augment', 'acquisitions', '2023', '2023', '2022', '2022', '2']
#
# Key phrases from page 11, chunk 6:
# ['controlling interests ’ proportionate share', 'cloud based industry solutions', 'controlling interests ’ share', 'presence across europe', 'initial recognition plus', 'identifiable net assets', 'digital transformation capabilities', 'initially measured either', 'controlling interests', 'controlling interests', 'acquiree ’', 'controlling shareholders', 'payments related', 'options issued', 'measurement basis', 'financial liabilities', 'fair value', 'business combinations', 'business combinations', 'subsequent changes', 'carrying amount', 'acquisition method', 'acquisition basis', 'interests', 'initially', 'subsequent', 'amount', 'acquisition', 'acquisition', 'using', 'subsidiaries', 'subsidiaries', 'scales', 'provisions', 'non', 'non', 'non', 'non', 'non', 'made', 'interest', 'ind', 'group', 'expand', 'equity', 'choice', 'accounted', 'accounted', '103']
#
# Key phrases from page 11, chunk 7:
# ['purchase price also includes', 'equity instruments issued', 'consolidated financial statements', 'estimated present value', 'option expires unexercised', 'purchase price', 'financial liabilities', 'fair value', 'fair value', 'fair value', 'carrying value', 'payments related', 'options issued', 'liabilities incurred', 'initially recognized', 'gross obligations', 'controlling interests', 'contingent consideration', 'business combinations', 'becomes exercisable', 'assets acquired', 'amount payable', 'subsequently measured', 'liabilities assumed', 'common control', 'assets transferred', 'option', 'transferred', 'options', 'measured', 'control', 'assumed', 'subsidiaries', 'reflect', 'order', 'non', 'liability', 'group', 'group', 'group', 'event', 'entities', 'derecognized', 'date', 'date', 'date', 'acquisition', 'acquisition', 'accounted', 'accounted']
#
# Key phrases from page 11, chunk 8:
# ['purchase price also includes', 'identifiable assets acquired', 'contingent liabilities assumed', 'contingent consideration', 'contingent consideration', 'contingent consideration', 'measured initially', 'fair value', 'fair value', 'fair value', 'fair value', 'consolidated statement', 'business combination', 'reporting date', 'liabilities', 'date', 'date', 'transferred', 'remeasured', 'recognized', 'profit', 'loss', 'group', 'control', 'changes', 'acquisition', 'acquisition', '10']
#
# Key phrases from page 12, chunk 1:
# ['infosys germany gmbh wholly owned step', 'insemi technology services private limited', 'semiconductor design services company headquartered', '34 million ), subject', '045 crore ), subject', 'infosys limited entered', 'infosys limited entered', 'tech holding gmbh', '₹ 280 crore', 'eur 450 million', 'retention bonuses totaling', 'equity share capital', 'equity share capital', 'customary closing adjustments', 'customary closing adjustments', 'consideration including earn', 'consideration including earn', 'approximately ₹ 4', 'services headquartered', 'proposed acquisitions', 'management incentives', 'leading provider', 'engineering r', 'definitive agreement', 'definitive agreement', 'april 18', 'acquire 100', 'acquire 100', 'outs amounting', 'january 11', 'germany', 'approximately', 'outs', '11', 'subsidiary', 'india', '2024', '2024']
#
# Key phrases from page 13, chunk 1:
# ...
#
# Key phrases from page 36, chunk 4:
# ['ordinary course legal actions', 'capital contracts primarily comprises', '3 legal proceedings', 'deposits )( 1', 'capital contracts', 'contracts remaining', 'ultimately concluded', 'reasonably expects', 'infrastructure facilities', 'group ’', 'financial condition', 'estimated amount', 'computer equipment', 'adverse effect', '1', 'results', 'provided', 'particulars', 'operations', 'net', 'material', 'executed', 'determined', 'commitments', 'advances', '35', '21', '2']
#
# Key phrases from page 37, chunk 1:
# ['chief financial officer effective april 1', 'independent director effective january 1', 'independent director effective april 19', 'independent director effective may 26', '22 related party transactions changes', 'president effective march 11', 'year ended march 31', 'leave till june 9', 'company effective march 31', 'chief financial officer', 'key management personnel', 'key management personnel', 'key management personnel', 'helene auriol potier', 'oddity gmbh renamed', 'wongdoody gmbh', 'uri levine', 'time directors', 'nitin paranjpe', 'nilanjan roy', 'mohit joshi', 'last date', 'jayesh sanghrajka', 'executive officers', 'company', 'changes', 'changes', 'changes', 'whole', 'transaction', 'subsidiaries', 'subsidiaries', 'retired', 'resigned', 'resigned', 'non', 'following', 'following', 'appointed', 'appointed', 'appointed', 'additional', '2024', '2024', '2024', '2024', '2023', '2023', '2023', '2023', '2']
#
# Key phrases from page 37, chunk 2:
# ['particulars 2024 2023 2024 2023 30 25 113 111 5 4 17 16 total 35 29 130 127', 'chief financial officer effective april 1', 'infosys bpm canada inc', 'infosys bpm canada inc', '2023', '2024', '2024', 'infosys bpm limited', 'infosys bpm limited', 'key management personnel', 'key management personnel', 'co ., ltd', '₹ crore', 'owned subsidiary', 'owned subsidiary', 'march 15', 'jayesh sanghrajka', 'executive officers', 'comprise directors', 'august 11', 'wongdoody limited', 'oddity limited', 'limited', 'co', 'wongdoody', 'oddity', 'wholly', 'wholly', 'transaction', 'taipei', 'taipei', 'table', 'shanghai', 'shanghai', 'renamed', 'renamed', 'incorporated', 'dissolved', 'describes', 'compensation', 'appointed']
#
# Key phrases from page 37, chunk 3:
# ['total employee stock compensation expense', 'three months ended march 31', 'towards key management personnel', 'towards key management personnel', 'year ended march 31', 'year ended march 31', 'year ended march 31', 'infosys bpm canada inc', 'short term employee benefits', 'term benefits based', 'infosys bpm limited', '₹ 68 crore', '₹ 49 crore', '₹ 17 crore', 'march 31', 'march 31', '1 )( 2', '8 crore', 'employment benefits', 'time directors', 'owned subsidiary', 'note 2', 'independent directors', 'include post', 'full names', 'controlled trusts', 'august 11', 'annual report', 'actuarial valuation', '11 ).', 'executive officers', '2023 includes', '2023 includes', 'benefits', 'limited', '2', '1', 'executive', '2023', '2023', 'wholly', 'whole', 'whole', 'subsidiaries', 'salaries', 'respectively', 'respectively', 'refer', 'refer', 'non', 'long', 'incorporated', 'done', 'details', 'company', 'company', 'company', 'commission', 'charge', 'charge', '2024', '2024']
#
# Key phrases from page 37, chunk 4:
# ['independent directors three months ended march 31', 'support services india private limited (“ danske', 'idunn information technology private limited', 'year ended march 31', 'liquidated effective july 14', 'oddity group services gmbh', 'short term employee benefits', 'infosys americas inc .,', 'oddity code gmbh merged', 'oddity waves gmbh', 'oddity space gmbh', 'oddity jungle gmbh', 'oddity gmbh ).', 'oddity code gmbh', '1 )( 2', 'infosys limited', '2023 infosys ltd', 'time directors', 'oddity code', 'infosys americas', 'wongdoody gmbh', 'wongdoody gmbh', 'september 1', 'april 1', 'voting interests', 'september 29', 'acquired 100', 'formerly known', 'executive officers', 'owned subsidiary', 'danske', 'danske', 'benefits', '2023', '2023', 'formerly', 'executive', 'subsidiary', 'subsidiary', '”).', 'wholly', 'whole', 'salaries', 'renamed', 'non', 'commission', 'become', '2024']
#
# Key phrases from page 37, chunk 5:
# ['idunn information technology private limited', 'liquidated effective november 1', '2023 stater participations b', 'stater participations b', 'kaleidoscope prototyping llc', 'stater belgium n', 'wholly owned subsidiary', 'wholly owned subsidiary', 'owned subsidiary', 'owned subsidiary', 'november 24', 'april 1', 'stater n', 'stater n', 'stater n', 'kaleidoscope animations', 'x18ao 36', 'oddity code', 'v ./', '2023', 'wholly', 'wholly', 'v', 'v', 'v', 'v', 'v', 'wongdoody', 'renamed', 'renamed', 'merged', 'formerly', 'danske', 'became', '2024']
#
# Key phrases from page 38, chunk 1:
# ['441 identifiable operating expenses 6', '454 allocated expenses', 'tech life sciences', 'services manufacturing hi', 'particulars financial services', '639 652 22', '514 701 21', '1 )* retail', '23 business segments', '325 6', '995 1', '762 1', '734 1', '681 1', '656 1', '248 1', '₹ crore', 'total revenue', 'operations 10', 'communic ation', '923 10', '102 37', '083 37', '825 5', '818 5', '666 5', '068 5', '010 5', '989 2', '869 2', '717 3', '614 3', '613 2', '591 3', '589 3', '316 2', '161 2', '078 2', '042 2', '033 2', '537 4', '429 4', '411 4', 'segments', '5', '3', '2', '2', '4', 'utilities', 'resources', 'energy']
#
# Key phrases from page 38, chunk 2:
# ['027 974 823 920 852 518 491 209 6', '034 840 909 928 505 462 254 6', '302 902 750 705 147 8', '081 803 632 222 8', '989 segment operating income 1', '729 671 finance cost', '998 unallocable expenses 1', '454 allocated expenses 2', '514 701 21', '864 810 1', '634 958 1', '6', '941 1', '734 1', '600 1', '431 1', '248 1', '163 1', '057 1', 'note 2', '869 2', '814 2', '784 2', '613 2', '161 2', '614 3', 'income', '2', 'refer', 'net', '17', '121']
#
# Key phrases from page 38, chunk 3:
# ['amortization — — three months ended march 31', '729 671 finance cost 110 82 profit', 'public business enterprises report information', '466 income tax expense 2', '332 net profit 7', 'business segment revenue information', 'march 31', 'segment reporting ind', 'individual customers invoiced', 'unallocable expenses 1', 'amortization 1', 'tax 10', 'note 2', 'cash expenses', '265 2', '163 1', '163 1', 'related disclosures', 'otherwise recognized', 'operating segments', 'operating segments', 'establishes standards', 'collated based', '975 6', '240 8', '134 depreciation', '121 non', 'income', 'revenue', 'net', '2', 'depreciation', '121', 'way', 'relation', 'refer', '2024', '2023', '17', '108']
#
# Key phrases from page 38, chunk 4:
# ['public business enterprises report information', 'chief operating decision maker', 'presented along business segments', 'segment reporting ind', 'operations predominantly relate', 'allocates resources based', 'end business solutions', 'enhance business performance', 'accounting principles used', 'various performance indicators', 'business segments', 'operating segments', 'operating segments', 'providing end', 'accounting policies', 'individual segments', 'related disclosures', 'record revenue', 'major customers', 'geographic areas', 'financial statements', 'establishes standards', 'enable clients', 'consistently applied', 'information', 'performance', 'way', 'set', 'services', 'products', 'preparation', 'group', 'group', 'expenditure', 'evaluates', 'codm', 'analysis', 'accordingly', '108']
#
# Key phrases from page 38, chunk 5:
# ['financial services operating segment', 'financial services reportable segments', 'finacle operating segment', 'consumer packaged goods', 'infosys public services', 'financial services', 'public services', 'operating segments', 'financial statements', 'segments represent', 'individual segments', 'business segments', 'telecom oem', 'record revenue', 'life sciences', 'economic characteristics', 'consistently applied', 'accounting policies', 'primarily enterprises', 'services', 'segments', 'enterprises', 'enterprises', 'enterprises', 'enterprises', 'enterprises', 'enterprises', 'enterprises', 'utilities', 'tech', 'similarity', 'set', 'retail', 'resources', 'preparation', 'media', 'manufacturing', 'logistics', 'japan', 'insurance', 'india', 'include', 'hi', 'healthcare', 'group', 'expenditure', 'energy', 'communication', 'china', 'businesses', 'aggregated']
#
# Key phrases from page 38, chunk 6:
# ['offshore software development centers', 'segments include expenses incurred', 'identifiable operating expenses', 'infosys public services', 'infosys public services', 'represents revenue generated', 'public services', 'public services', 'total expenses', 'site expenses', 'individually identifiable', 'certain expenses', 'allocated expenses', 'rendering services', 'revenue generated', 'used interchangeably', 'underlying assets', 'specifically allocable', 'specific segments', 'significant component', 'management believes', 'customers located', 'associated efforts', 'categorized based', 'segments', 'segments', 'revenue', 'revenue', 'categorized', 'segment', 'segment', 'relation', 'relation', 'practical', 'japan', 'japan', 'items', 'india', 'india', 'group', 'form', 'enterprises', 'enterprises', 'depreciation', 'china', 'china', 'businesses', 'amortization']
#
# Key phrases from page 38, chunk 7:
# ['provide segment disclosures relating', 'provide segment disclosures relating', 'x19aox18ao 37', 'used interchangeably', 'used interchangeably', 'total income', 'specifically allocable', 'separately disclosed', 'note 2', 'meaningful segregation', 'management believes', 'management believes', 'liabilities used', 'liabilities since', 'geographic locations', 'available data', 'underlying assets', 'total assets', 'specific segments', 'reportable segments', '16 revenue', 'total expenses', 'segments', 'assets', 'revenue', 'expenses', 'expenses', 'unallocated', 'practical', 'practicable', 'operations', 'onerous', 'identified', 'group', 'group', 'given', 'disclosure', 'currently', 'costs', 'business', 'adjusted', 'accordingly']
#
# Key phrases from page 39, chunk 1:
# ['767 identifiable operating expenses 24', '993 allocated expenses', 'tech life sciences', 'services manufacturing hi', 'particulars financial services', '1 )* retail', '877 24', '₹ crore', 'total revenue', 'operations 42', 'communic ation', '991 20', '990 10', '938 89', '923 12', '892 11', '867 10', '838 14', '801 84', '782 11', '763 21', '758 153', '704 11', '670 43', '596 7', '539 19', '504 17', '493 6', '411 11', '298 12', '232 6', '204 18', '188 146', '158 22', '101 9', '086 18', '071 10', '035 22', '035 11', '834 2', '716 2', '515 4', '085 4', '959 5', '4', '2', '5', 'utilities', 'segments', 'resources', 'energy', '3']
#
# Key phrases from page 39, chunk 2:
# ['644 segment operating income 9', '993 allocated expenses 8', '701 finance cost 470', '130 unallocable expenses 4', '898 760 36', '566 339 35', '101 9', '678 4', '523 4', 'note 2', '990 10', '959 5', '959 2', '949 1', '930 3', '923 12', '918 3', '916 3', '901 1', '892 11', '882 3', '843 6', '834 2', '801 84', '759 5', '711 2', '688 5', '685 1', '674 3', '505 2', '493 6', '461 3', '429 1', '425 10', '396 3', '368 7', '324 6', '232 3', '226 3', '197 3', '155 3', '153 2', '113 2', '060 27', '052 3', '048 26', '026 1', 'income', '4', 'refer', 'net', '24', '225', '17']
#
# Key phrases from page 39, chunk 3:
# ['701 finance cost 470 284 profit', '322 income tax expense 9', '214 net profit 26', 'financial services include enterprises', 'life sciences includes enterprises', 'consumer packaged goods', 'amortization — —', 'amortization expense 4', 'retail includes enterprises', 'communication includes enterprises', 'unallocable expenses 4', 'life sciences', 'financial services', 'tax 35', '740 9', 'cash expenses', 'telecom oem', 'health care', '988 33', '678 4', '678 4', '248 24', 'note 2', '711 2', '225 non', '108 depreciation', 'income', 'net', 'retail', 'communication', '4', '4', '2', 'depreciation', '225', 'refer', 'media', 'logistics', 'insurance', '3', '17', '1']
#
# Key phrases from page 39, chunk 4:
# ['others include operating segments', 'year ended march 31', 'year ended march 31', 'life sciences includes enterprises', 'refer note 2', 'mccamish cybersecurity incident', 'client individually accounted', 'infosys public services', 'communication includes enterprises', 'march 31', 'march 31', 'life sciences', 'public services', 'includes impact', 'three months', 'telecom oem', 'significant clients', 'health care', 'enterprises', 'communication', 'revenues', 'respectively', 'media', 'japan', 'india', 'china', 'businesses', 'account', '5', '4', '38', '3', '3', '21', '2024', '2024', '2023', '2023', '10']
#
# Key phrases from page 40, chunk 1:
# ['2024 2023 2024 2023 revenue', '260 total operating expenses 3', '24 function wise classification', '414 operating expenses selling', '353 gross profit 11', '509 operating profit', 'marketing expenses 1', 'administration expenses 1', 'condensed consolidated statement', '554 3', '175 11', '819 1', '735 1', '₹ crore', 'sales 26', 'particulars note', '973 6', '923 37', '894 7', '767 cost', '748 26', '670 146', '659 6', '553 14', '537 7', '510 13', '441 153', '430 46', '413 102', '257 44', '249 general', '16 37', '011 107', 'operations 2', 'profit', '2', 'loss']
#
# Key phrases from page 40, chunk 2:
# ['701 finance cost 110 82 470 284 profit', '509 operating profit 7', 'total operating expenses 3', '287 deferred tax 2', '729 671 4', '322 tax expense', 'current tax 2', '092 72 1', 'tax 10', '621 7', '554 3', 'net 2', '711 2', '173 2', '17 2', '15 1', '15 1', 'profit', '988 33', '877 31', '747 30', '553 14', '510 13', '466 35', '390 9', '260 8', '240 8', 'period', 'income', '905', '73', '350']
#
# Key phrases from page 40, chunk 3:
# ['net 26 25 120 8 equity instruments', '14 10 139 1 items', 'net defined benefit liability', 'loss fair value changes', '092 72 1', 'deferred tax 2', 'comprehensive income items', 'cash flow hedge', '134 26', 'loss remeasurement', 'comprehensive income', '15 1', 'reclassified subsequently', 'reclassified subsequently', 'derivatives designated', '975 6', '248 24', 'period 7', 'net', 'net', '7', '15', 'profit', 'profit', 'profit', 'asset', '73', '350', '19', '12', '108']
#
# Key phrases from page 40, chunk 4:
# ['61 226 776 fair value changes', '149 520 514 total comprehensive income', 'loss fair value changes', '139 381 513 total', 'net 37 42 144', 'net 28 36 11', 'loss ), net', 'cash flow hedge', 'comprehensive income', 'reclassified subsequently', 'foreign operations', 'exchange differences', 'derivatives designated', 'translation', 'tax', 'profit', 'period', 'items', 'investments', '7', '256', '231', '166', '152']
#
# Key phrases from page 40, chunk 5:
# ['149 520 514 total comprehensive income', 'controlling interests 6 6 15 13 7', '108 total comprehensive income attributable', '622 profit attributable', 'controlling interests', '975 6', '969 6', '823 6', '821 6', 'period 7', 'company 7', 'company 7', '768 24', '754 24', '598 non', '283 26', '276 26', '248 24', '233 24', '134 26', '128 26', '095 non', 'owners', 'owners', '152']
#
# Key phrases from page 40, chunk 6:
# ['sundaram salil parekh bobby parikh lead independent director chief executive officer director', '2024 chief financial officer company secretary year ended march 31', 'controlling interests 2 7 14 24 7', 'three months ended march 31', 'managing director bengaluru jayesh sanghrajka', 'company 7', 'manikantha april 18', '768 24', '754 24', 'x20ao 39', 'infosys limited', '823 6', '821 6', '598 non', '283 26', '276 26', 'owners', 'g', 'directors', 'board', 'behalf', '622']

# %% [markdown]
# # Step 3

# %%
pip install sentence-transformers
# Out:
# Requirement already satisfied: sentence-transformers in /usr/local/lib/python3.11/dist-packages (3.3.1)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (4.47.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (4.67.1)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (2.5.1+cu121)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (1.6.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (1.13.1)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (0.27.1)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (11.1.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2024.10.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (3.1.5)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (12.1.105)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (1.13.1)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.11/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.11.0->sentence-transformers) (12.6.85)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (1.26.4)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.5.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->sentence-transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->sentence-transformers) (3.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2024.12.14)

# %%
from sentence_transformers import SentenceTransformer

model = SentenceTransformer('all-MiniLM-L6-v2')

def get_embedding(phrase):
    embedding = model.encode(phrase)
    return embedding

phrase_embeddings = {}

# Generate embeddings for each phrase
for (page, chunk_number), phrases in chunk_phrases.items():
    embeddings = [get_embedding(phrase) for phrase in phrases]
    phrase_embeddings[(page, chunk_number)] = list(zip(phrases, embeddings))

excel_data = []
for (page, chunk_number), phrases in phrase_embeddings.items():
    for phrase, embedding in phrases:
        excel_data.append({ "Page": page, "Chunk": chunk_number, "Phrase": phrase, "Embedding": embedding })

import pandas as pd
df = pd.DataFrame(excel_data)

# Save to Excel
excel_filename = "phrases_embeddings.xlsx"
df.to_excel(excel_filename, index=False)
print(f"Embeddings saved to {excel_filename}")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.7k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Embeddings saved to phrases_embeddings.xlsx

# %%
def extract_phrases_from_query(query):
    rake.extract_keywords_from_text(query)
    return rake.get_ranked_phrases()
# Example query
# query = "What is the gross profit for Q3 2024?"
# # Extract phrases from the query
# query_phrases = extract_phrases_from_query(query)
# Output query phrases
# print(f"Query phrases:\n{query_phrases}\n")

def get_embeddings(phrase):
    embedding = model.encode(phrase)
    return embedding

# query_embeddings = get_embeddings(query_phrases)

import numpy as np
from scipy.spatial.distance import cosine

#Function to calculate cosine similarity
def cosine_similarity(embedding1, embedding2):
    return 1 - cosine(embedding1, embedding2)
# Out:
# Query phrases:
# ['q3 2024', 'gross profit']

# %% [markdown]
# # Step 4

# %%
pip install transformers
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (4.47.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.24.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.27.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.5.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.24.0->transformers) (2024.10.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.24.0->transformers) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2024.12.14)

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer

# Load a pre-trained text generation model
model_name = "EleutherAI/gpt-neo-1.3B"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model_2 = AutoModelForCausalLM.from_pretrained(model_name)

def truncate_input(context, query, model, max_new_tokens=300):
    max_input_length = model.config.max_position_embeddings - max_new_tokens
    prompt = f"Answer the following query based on the provided text:\n\n{context}\n\nQuery: {query}\nAnswer:"
    tokenized_input = tokenizer(prompt, return_tensors="pt", truncation=True, max_length=max_input_length)
    return tokenized_input


# Function to generate a response
def generate_response(context, query, max_new_tokens=300, temperature=0.7):

    inputs = truncate_input(context, query, model_2, max_new_tokens)

    outputs = model_2.generate(
        inputs["input_ids"],
        attention_mask=inputs["attention_mask"],
        max_new_tokens=max_new_tokens,
        temperature=temperature,
        do_sample=True,
        pad_token_id=tokenizer.eos_token_id
    )

    response = tokenizer.decode(outputs[0], skip_special_tokens=True)
    return response[len(inputs["input_ids"][0]):].strip()
# Out:
# tokenizer_config.json:   0%|          | 0.00/200 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.35k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/798k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/90.0 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/5.31G [00:00<?, ?B/s]

# %%
def find_relevant_chunks(query, page_chunks, phrase_embeddings, model):
    # Extract query phrases
    query_phrases = extract_phrases_from_query(query)
    query_embeddings = [get_embedding(phrase) for phrase in query_phrases]

    # Calculate cosine similarities
    chunk_similarities = {}
    for (page, chunk_number), phrases in phrase_embeddings.items():
        similarities = []
        for phrase, embedding in phrases:
            phrase_similarities = [cosine_similarity(embedding, query_embedding) for query_embedding in query_embeddings]
            similarities.append(max(phrase_similarities))

        # Average similarity for the chunk
        average_similarity = np.mean(similarities)
        chunk_similarities[(page, chunk_number)] = average_similarity


    top_chunks = sorted(chunk_similarities.items(), key=lambda x: x[1], reverse=True)[:5]

    selected_chunks = []
    for (page, chunk_number), similarity in top_chunks:
        selected_chunks.append(page_chunks[page][chunk_number - 1])

    return selected_chunks

# %%
print("Welcome to the Financial QA Chatbot! Ask your questions or type 'exit' to quit.")
while True:
    query = input("You: ")
    if query.lower() == "exit":
        print("Chatbot: Goodbye!")
        break

    # Find relevant chunks to generate a response
    selected_chunks = find_relevant_chunks(query, page_chunks, phrase_embeddings, model)
    context = "\n\n".join(selected_chunks)
    answer = generate_response(context, query)

    print(f"Chatbot: {answer}")
# Out:
# Welcome to the Financial QA Chatbot! Ask your questions or type 'exit' to quit.
# Chatbot: her comprehensive income, net*
#
# 2.17 OTHER INCOME, NET
# Accounting policy
# Foreign currency
# Accounting policy
# Functional currency
# Transactions and translations
# Government grant
# Other income for the three months and year ended March 31, 2024 and March 31, 2023 is as follows:
# (In ₹ crore)
# Particulars
# 2024
# 2023
# 2024
# 2023
# Interest income on financial assets carried at amortized cost
# Tax free bonds and Government bonds
#                         31                         36                            131                      149
# Deposit with Bank and others
#                       222                       161                            929                      712
#                       318
# 231                     —                         —                             —                        —                   —
#                          —                          —                             —                        —                   —
# Accounts payable
# Accounts payable
# Receivables
# Accounts payable
# Receivables
# Receivables
# Receivables
# Receivables
# Receivables
# Receivables
# Receivables
# Receivables
# Receivables
# Chatbot: ss profit
#                      11,175                      11,430                    46,257                    44,414
# Operating expenses
# Selling and marketing expenses
#                        1,735                        1,659                      6,973                      6,249
# General and administration expenses
#                        1,819                        1,894                      7,537                      7,260
# Total operating expenses
#                        3,554                        3,553                    14,510                    13,509
# Operating profit
#
# 2.4
# INVESTMENTS
# (In ₹ crore)
# Particulars
# March 31, 2024
# March 31, 2023
# Non-current Investments
# Unquoted
# Investments carried at fair value through other comprehensive income
# Preference securities
#                                      91                                 193
# Equity securities
#                                        2                                     3
#                                 93                             196
# Investments carried at fair value through profit or loss
# Target maturity fund units
#                                    431                                 402
# Others (1)
#                                    198                                 169
# Total investments
#                                    637                                 641
# Equity securities
#                                        12                                  20
# Equity securities
#                                         8                                    9
# Income before income taxes
#                                         0
# You: exit
# Chatbot: Goodbye!
